# %% [markdown]
# # * Anotações

# %%
# Anotações

# 1. Comando que retorna a frequência de dados duplicados em uma coluna
# value_counts()

# 2. Comando que retira os dados duplicados em uma coluna e retorna um df
# drop_duplicates()

# 3. Removendo coluna e salvando o no df no df original:
# df = df.drop(columns=['nome_da_coluna_que_se_deseja_remover'])

# 4. o comando .tolist() converte objetos em listas

# %% [markdown]
# # 0.0 Imports

# %%
import pandas as pd
import numpy as np
import streamlit as st
import plotly.express as px

import inflection

# %% [markdown]
# # 0.1. Helper Variables

# %%
COUNTRIES = {
    1: "India",
    14: "Australia",
    30: "Brazil",
    37: "Canada",
    94: "Indonesia",
    148: "New Zeland",
    162: "Philippines",
    166: "Qatar",
    184: "Singapure",
    189: "South Africa",
    191: "Sri Lanka",
    208: "Turkey",
    214: "United Arab Emirates",
    215: "England",
    216: "United States of America",
}


COLORS = {
    "3F7E00": "darkgreen",
    "5BA829": "green",
    "9ACD32": "lightgreen",
    "CDD614": "orange",
    "FFBA00": "red",
    "CBCBC8": "darkred",
    "FF7800": "darkred",
}

# %% [markdown]
# # 0.2. Helper Functions

# %%
def show_dataframe_dimensions(dataframe):
    print(f"Number of Rows: {dataframe.shape[0]}")
    print(f"Number of Columns: {dataframe.shape[1]}")
    
    return None

# %%
def get_numerical_attributes(dataframe):
    return dataframe.select_dtypes(include=['int64','float64'])

# %%
def get_first_order_statistics(dataframe):
    # Central Tendency Metrics
    mean = pd.DataFrame(dataframe.apply(np.mean)).T
    median = pd.DataFrame(dataframe.apply(np.median)).T

    # Dispersion Metrics
    min_ = pd.DataFrame(dataframe.apply(min)).T
    max_ = pd.DataFrame(dataframe.apply(max)).T
    range_ = pd.DataFrame(dataframe.apply(lambda x: x.max() - x.min())).T
    std = pd.DataFrame(dataframe.apply(np.std)).T
    skew = pd.DataFrame(dataframe.apply(lambda x: x.skew())).T
    kurtosis = pd.DataFrame(dataframe.apply(lambda x: x.kurtosis())).T

    # Metrics Concatenation
    m = pd.concat([min_, max_, range_, mean, median, std, skew, kurtosis]).T.reset_index()
    m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
    
    return m

# %%
def rename_columns(dataframe):
    df = dataframe.copy()

    title = lambda x: inflection.titleize(x)

    snakecase = lambda x: inflection.underscore(x)

    spaces = lambda x: x.replace(" ", "")

    cols_old = list(df.columns)

    cols_old = list(map(title, cols_old))

    cols_old = list(map(spaces, cols_old))

    cols_new = list(map(snakecase, cols_old))

    df.columns = cols_new

    return df

# %%
def country_name(country_id):
    return COUNTRIES[country_id]

# %%
def color_name(color_code):
    return COLORS[color_code]

# %%
def create_price_tye(price_range):
    if price_range == 1:
        return "cheap"
    elif price_range == 2:
        return "normal"
    elif price_range == 3:
        return "expensive"
    else:
        return "gourmet"

# %%
def adjust_columns_order(dataframe):
    df = dataframe.copy()

    new_cols_order = [
        "restaurant_id",
        "restaurant_name",
        "country",
        "city",
        "address",
        "locality",
        "locality_verbose",
        "longitude",
        "latitude",
        "cuisines",
        "price_type",
        "average_cost_for_two",
        "currency",
        "has_table_booking",
        "has_online_delivery",
        "is_delivering_now",
        "aggregate_rating",
        "rating_color",
        "color_name",
        "rating_text",
        "votes",
    ]

    return df.loc[:, new_cols_order]

# %%
def process_data(file_path):
    df = pd.read_csv(file_path)

    df = df.dropna()

    df = rename_columns(df)

    df["price_type"] = df.loc[:, "price_range"].apply(lambda x: create_price_tye(x))

    df["country"] = df.loc[:, "country_code"].apply(lambda x: country_name(x))

    df["color_name"] = df.loc[:, "rating_color"].apply(lambda x: color_name(x))

    df["cuisines"] = df.loc[:, "cuisines"].apply(lambda x: x.split(",")[0])

    df = df.drop_duplicates()

    df = adjust_columns_order(df)
    
    df = df.reset_index()
    
    df = df.drop(columns=['index'])

    df.to_csv("dataset/processed/data.csv", index=False)

    return df

# %% [markdown]
# # 0.3. Helper Configurations

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# # 0.4. Load Data

# %%
RAW_DATA_PATH = f"dataset/raw/data.csv"
df_raw = pd.read_csv(RAW_DATA_PATH)
df_raw.head()
# Out:
#    Restaurant ID             Restaurant Name  Country Code            City  \
# 0        6310675  Mama Lou's Italian Kitchen           162  Las Piñas City
# 1        6310675  Mama Lou's Italian Kitchen           162  Las Piñas City
# 2        6314542                   Blackbird           162     Makati City
# 3        6301293                    Banapple           162     Makati City
# 4        6315689                    Bad Bird           162     Makati City
#
#                                              Address  \
# 0  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 1  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 2  Nielson Tower, Ayala Triangle Gardens, Salcedo...
# 3  Ayala Triangle Gardens, Salcedo Village, Makat...
# 4  Hole In The Wall, Floor 4, Century City Mall, ...
#
#                                             Locality  \
# 0                                   BF International
# 1                                   BF International
# 2  Ayala Triangle Gardens, Salcedo Village, Makat...
# 3  Ayala Triangle Gardens, Salcedo Village, Makat...
# 4          Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0                   BF International, Las Piñas City  121.009787  14.447615
# 1                   BF International, Las Piñas City  121.009787  14.447615
# 2  Ayala Triangle Gardens, Salcedo Village, Makat...  121.024562  14.556042
# 3  Ayala Triangle Gardens, Salcedo Village, Makat...  121.023171  14.556196
# 4  Century City Mall, Poblacion, Makati City, Mak...  121.027708  14.565899
#
#                               Cuisines  Average Cost for two  \
# 0                              Italian                  1100
# 1                              Italian                  1100
# 2                      European, Asian                  3100
# 3  Filipino, American, Italian, Bakery                   800
# 4                             American                   700
#
#            Currency  Has Table booking  Has Online delivery  \
# 0  Botswana Pula(P)                  1                    0
# 1  Botswana Pula(P)                  1                    0
# 2  Botswana Pula(P)                  0                    0
# 3  Botswana Pula(P)                  0                    0
# 4  Botswana Pula(P)                  0                    0
#
#    Is delivering now  Switch to order menu  Price range  Aggregate rating  \
# 0                  0                     0            3               4.6
# 1                  0                     0            3               4.6
# 2                  0                     0            4               4.7
# 3                  0                     0            3               4.4
# 4                  0                     0            3               4.4
#
#   Rating color Rating text  Votes
# 0       3F7E00   Excellent    619
# 1       3F7E00   Excellent    619
# 2       3F7E00   Excellent    469
# 3       5BA829   Very Good    867
# 4       5BA829   Very Good    858

# %% [markdown]
# # 1.0. DATA DESCRIPTION

# %%
df1 = df_raw.copy()
df1.head()
# Out:
#    Restaurant ID             Restaurant Name  Country Code            City  \
# 0        6310675  Mama Lou's Italian Kitchen           162  Las Piñas City
# 1        6310675  Mama Lou's Italian Kitchen           162  Las Piñas City
# 2        6314542                   Blackbird           162     Makati City
# 3        6301293                    Banapple           162     Makati City
# 4        6315689                    Bad Bird           162     Makati City
#
#                                              Address  \
# 0  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 1  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 2  Nielson Tower, Ayala Triangle Gardens, Salcedo...
# 3  Ayala Triangle Gardens, Salcedo Village, Makat...
# 4  Hole In The Wall, Floor 4, Century City Mall, ...
#
#                                             Locality  \
# 0                                   BF International
# 1                                   BF International
# 2  Ayala Triangle Gardens, Salcedo Village, Makat...
# 3  Ayala Triangle Gardens, Salcedo Village, Makat...
# 4          Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0                   BF International, Las Piñas City  121.009787  14.447615
# 1                   BF International, Las Piñas City  121.009787  14.447615
# 2  Ayala Triangle Gardens, Salcedo Village, Makat...  121.024562  14.556042
# 3  Ayala Triangle Gardens, Salcedo Village, Makat...  121.023171  14.556196
# 4  Century City Mall, Poblacion, Makati City, Mak...  121.027708  14.565899
#
#                               Cuisines  Average Cost for two  \
# 0                              Italian                  1100
# 1                              Italian                  1100
# 2                      European, Asian                  3100
# 3  Filipino, American, Italian, Bakery                   800
# 4                             American                   700
#
#            Currency  Has Table booking  Has Online delivery  \
# 0  Botswana Pula(P)                  1                    0
# 1  Botswana Pula(P)                  1                    0
# 2  Botswana Pula(P)                  0                    0
# 3  Botswana Pula(P)                  0                    0
# 4  Botswana Pula(P)                  0                    0
#
#    Is delivering now  Switch to order menu  Price range  Aggregate rating  \
# 0                  0                     0            3               4.6
# 1                  0                     0            3               4.6
# 2                  0                     0            4               4.7
# 3                  0                     0            3               4.4
# 4                  0                     0            3               4.4
#
#   Rating color Rating text  Votes
# 0       3F7E00   Excellent    619
# 1       3F7E00   Excellent    619
# 2       3F7E00   Excellent    469
# 3       5BA829   Very Good    867
# 4       5BA829   Very Good    858

# %% [markdown]
# # 1.1. Columns Description

# %% [markdown]
# |Column|Description|
# |------|-----------|
# |Restaurant ID|ID do restaurante|
# |Restaurant Name|Nome do Restaurante|
# |Country Code|Código do País|
# |City|Nome da Cidade onde o restaurante está|
# |Address|Endereço do restaurante|
# |Locality|Localização e pontos de referência do restaurante|
# |Locality Verbose|Localização e pontos de referência do restaurante (Mais informações)|
# |Longitude|Ponto geográfico de Longitude do Restaurante|
# |Latitude|Ponto geográfico de Latitude do Restaurante|
# |Cuisines|Tipos de Culinária servidos no restaurante|
# |Average Cost for two|Preço Médio de um prato para duas pessoas no restaurante|
# |Currency|Moeda do país|
# |Has Table booking|Se o restaurante possui serviços de reserva; 1 - Sim; 0 - Não|
# |Has Online delivery|Se o restaurante possui serviços de pedido on-line; 1 - Sim; 0 - Não|
# |Is delivering now|Se o restaurante faz entregas; 1 - Sim; 0 - Não|
# |Switch to order menu|-|
# |Price range|Variação de preços do restaurante; 1 a 4 - Quanto maior o valor, mais caro serão os pratos|
# |Aggregate rating|Nota média do restaurante|
# |Rating color|Código Hexadecimal da cor do restaurante com base em sua nota média|
# |Rating text|Categoria em que o restaurante está com base em sua nota média|
# |Votes|Quantidade de avaliações que o restaurante já recebeu|

# %% [markdown]
# # 1.2. Rename Columns

# %%
df1 = rename_columns(df1)
df1.head()
# Out:
#    restaurant_id             restaurant_name  country_code            city  \
# 0        6310675  Mama Lou's Italian Kitchen           162  Las Piñas City
# 1        6310675  Mama Lou's Italian Kitchen           162  Las Piñas City
# 2        6314542                   Blackbird           162     Makati City
# 3        6301293                    Banapple           162     Makati City
# 4        6315689                    Bad Bird           162     Makati City
#
#                                              address  \
# 0  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 1  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 2  Nielson Tower, Ayala Triangle Gardens, Salcedo...
# 3  Ayala Triangle Gardens, Salcedo Village, Makat...
# 4  Hole In The Wall, Floor 4, Century City Mall, ...
#
#                                             locality  \
# 0                                   BF International
# 1                                   BF International
# 2  Ayala Triangle Gardens, Salcedo Village, Makat...
# 3  Ayala Triangle Gardens, Salcedo Village, Makat...
# 4          Century City Mall, Poblacion, Makati City
#
#                                     locality_verbose   longitude   latitude  \
# 0                   BF International, Las Piñas City  121.009787  14.447615
# 1                   BF International, Las Piñas City  121.009787  14.447615
# 2  Ayala Triangle Gardens, Salcedo Village, Makat...  121.024562  14.556042
# 3  Ayala Triangle Gardens, Salcedo Village, Makat...  121.023171  14.556196
# 4  Century City Mall, Poblacion, Makati City, Mak...  121.027708  14.565899
#
#                               cuisines  average_cost_for_two  \
# 0                              Italian                  1100
# 1                              Italian                  1100
# 2                      European, Asian                  3100
# 3  Filipino, American, Italian, Bakery                   800
# 4                             American                   700
#
#            currency  has_table_booking  has_online_delivery  \
# 0  Botswana Pula(P)                  1                    0
# 1  Botswana Pula(P)                  1                    0
# 2  Botswana Pula(P)                  0                    0
# 3  Botswana Pula(P)                  0                    0
# 4  Botswana Pula(P)                  0                    0
#
#    is_delivering_now  switch_to_order_menu  price_range  aggregate_rating  \
# 0                  0                     0            3               4.6
# 1                  0                     0            3               4.6
# 2                  0                     0            4               4.7
# 3                  0                     0            3               4.4
# 4                  0                     0            3               4.4
#
#   rating_color rating_text  votes
# 0       3F7E00   Excellent    619
# 1       3F7E00   Excellent    619
# 2       3F7E00   Excellent    469
# 3       5BA829   Very Good    867
# 4       5BA829   Very Good    858

# %% [markdown]
# # 1.3. Data Dimensions

# %%
show_dataframe_dimensions(df1)
# Out:
# Number of Rows: 7527
# Number of Columns: 21

# %% [markdown]
# # 1.4. Data Types

# %%
df1.dtypes
# Out:
# restaurant_id             int64
# restaurant_name          object
# country_code              int64
# city                     object
# address                  object
# locality                 object
# locality_verbose         object
# longitude               float64
# latitude                float64
# cuisines                 object
# average_cost_for_two      int64
# currency                 object
# has_table_booking         int64
# has_online_delivery       int64
# is_delivering_now         int64
# switch_to_order_menu      int64
# price_range               int64
# aggregate_rating        float64
# rating_color             object
# rating_text              object
# votes                     int64
# dtype: object

# %% [markdown]
# # 1.5. Check NA

# %%
df1.isna().sum()
# Out:
# restaurant_id            0
# restaurant_name          0
# country_code             0
# city                     0
# address                  0
# locality                 0
# locality_verbose         0
# longitude                0
# latitude                 0
# cuisines                15
# average_cost_for_two     0
# currency                 0
# has_table_booking        0
# has_online_delivery      0
# is_delivering_now        0
# switch_to_order_menu     0
# price_range              0
# aggregate_rating         0
# rating_color             0
# rating_text              0
# votes                    0
# dtype: int64

# %%
df1
# Out:
#       restaurant_id                    restaurant_name  country_code  \
# 0           6310675         Mama Lou's Italian Kitchen           162
# 1           6310675         Mama Lou's Italian Kitchen           162
# 2           6314542                          Blackbird           162
# 3           6301293                           Banapple           162
# 4           6315689                           Bad Bird           162
# ...             ...                                ...           ...
# 7522        5912546                             Eataly           208
# 7523        5913006  Tarihi Çınaraltı Aile Çay Bahçesi           208
# 7524        5923535             Boon Cafe & Restaurant           208
# 7525        5914190                   Kanaat Lokantası           208
# 7526        5913508                            Katibim           208
#
#                 city                                            address  \
# 0     Las Piñas City  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 1     Las Piñas City  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 2        Makati City  Nielson Tower, Ayala Triangle Gardens, Salcedo...
# 3        Makati City  Ayala Triangle Gardens, Salcedo Village, Makat...
# 4        Makati City  Hole In The Wall, Floor 4, Century City Mall, ...
# ...              ...                                                ...
# 7522        İstanbul  Zorlu Center AVM, Köprü Katı, Levazım Mahalles...
# 7523        İstanbul  Çengelköy Mahallesi, Çınaraltı Camii Sokak, No...
# 7524        İstanbul  Çengelköy Mahallesi, Çengelköy Caddesi, Kara S...
# 7525        İstanbul  Sultantepe Mahallesi, Selmani Pak Caddesi, No ...
# 7526        İstanbul  Mimar Sinan Mahallesi, Harem Sahilyolu, No 53,...
#
#                                                locality  \
# 0                                      BF International
# 1                                      BF International
# 2     Ayala Triangle Gardens, Salcedo Village, Makat...
# 3     Ayala Triangle Gardens, Salcedo Village, Makat...
# 4             Century City Mall, Poblacion, Makati City
# ...                                                 ...
# 7522                Zorlu Center AVM, Levazım, Beşiktaş
# 7523                                   Çengelköy Merkez
# 7524                                   Çengelköy Merkez
# 7525                                     Üsküdar Merkez
# 7526                                     Üsküdar Merkez
#
#                                        locality_verbose   longitude  \
# 0                      BF International, Las Piñas City  121.009787
# 1                      BF International, Las Piñas City  121.009787
# 2     Ayala Triangle Gardens, Salcedo Village, Makat...  121.024562
# 3     Ayala Triangle Gardens, Salcedo Village, Makat...  121.023171
# 4     Century City Mall, Poblacion, Makati City, Mak...  121.027708
# ...                                                 ...         ...
# 7522      Zorlu Center AVM, Levazım, Beşiktaş, İstanbul   29.017326
# 7523                         Çengelköy Merkez, İstanbul   29.052620
# 7524                         Çengelköy Merkez, İstanbul   29.052623
# 7525                           Üsküdar Merkez, İstanbul   29.016590
# 7526                           Üsküdar Merkez, İstanbul   29.010808
#
#        latitude                                 cuisines  \
# 0     14.447615                                  Italian
# 1     14.447615                                  Italian
# 2     14.556042                          European, Asian
# 3     14.556196      Filipino, American, Italian, Bakery
# 4     14.565899                                 American
# ...         ...                                      ...
# 7522  41.065322               Italian, Pizza, Fresh Fish
# 7523  41.050280  Fast Food, Izgara, Seafood, Tea, Coffee
# 7524  41.050717                          Restaurant Cafe
# 7525  41.025741                        Home-made, Izgara
# 7526  41.025501    Restaurant Cafe, Kebab, Turkish Pizza
#
#       average_cost_for_two          currency  has_table_booking  \
# 0                     1100  Botswana Pula(P)                  1
# 1                     1100  Botswana Pula(P)                  1
# 2                     3100  Botswana Pula(P)                  0
# 3                      800  Botswana Pula(P)                  0
# 4                      700  Botswana Pula(P)                  0
# ...                    ...               ...                ...
# 7522                   300  Turkish Lira(TL)                  0
# 7523                    45  Turkish Lira(TL)                  0
# 7524                   140  Turkish Lira(TL)                  0
# 7525                    95  Turkish Lira(TL)                  0
# 7526                   150  Turkish Lira(TL)                  0
#
#       has_online_delivery  is_delivering_now  switch_to_order_menu  \
# 0                       0                  0                     0
# 1                       0                  0                     0
# 2                       0                  0                     0
# 3                       0                  0                     0
# 4                       0                  0                     0
# ...                   ...                ...                   ...
# 7522                    0                  0                     0
# 7523                    0                  0                     0
# 7524                    0                  0                     0
# 7525                    0                  0                     0
# 7526                    0                  0                     0
#
#       price_range  aggregate_rating rating_color rating_text  votes
# 0               3               4.6       3F7E00   Excellent    619
# 1               3               4.6       3F7E00   Excellent    619
# 2               4               4.7       3F7E00   Excellent    469
# 3               3               4.4       5BA829   Very Good    867
# 4               3               4.4       5BA829   Very Good    858
# ...           ...               ...          ...         ...    ...
# 7522            4               4.3       5BA829   Very Good   1367
# 7523            2               4.5       3F7E00   Excellent   1172
# 7524            4               4.2       5BA829   Very Good   1160
# 7525            3               4.0       5BA829   Very Good    770
# 7526            4               4.2       5BA829   Very Good   1141
#
# [7527 rows x 21 columns]

# %% [markdown]
# # *All types of cuisines

# %%
df1.loc[:, 'cuisines'].unique().tolist()
# Out:
# ['Italian',
#  'European, Asian',
#  'Filipino, American, Italian, Bakery',
#  'American',
#  'Filipino',
#  'Korean, Grill',
#  'American, Filipino, Coffee',
#  'Pizza, Italian',
#  'Taiwanese',
#  'Japanese, Latin American',
#  'Japanese',
#  'Italian, Pizza',
#  'American, Filipino',
#  'Japanese, Sushi',
#  'Coffee, American, European',
#  'Japanese, Ramen',
#  'American, Italian, Bakery, Coffee',
#  'Chinese',
#  'Japanese, Korean',
#  'Coffee',
#  'European, Desserts',
#  'European, Steak, Bakery, Desserts',
#  'Filipino, Chinese',
#  'Seafood, Filipino, Asian, European',
#  'European, Asian, Indian',
#  'Korean',
#  'Filipino, Mexican',
#  'American, Burger',
#  'Singaporean, Street Food',
#  'Vietnamese',
#  'Latin American, Street Food',
#  'Filipino, Asian',
#  'Korean, Korean BBQ',
#  'Filipino, Coffee',
#  'European, Italian',
#  'American, Asian',
#  'European, American',
#  'European, Filipino, American',
#  'American, European',
#  'Coffee, Japanese',
#  'Japanese, Asian',
#  'Seafood, American, Mediterranean, Japanese',
#  'European, Filipino',
#  'Healthy Food',
#  'Cafe, Desserts',
#  'Fast Food, French',
#  'Brazilian',
#  'Argentine, Contemporary',
#  'Arabian',
#  'Cafe',
#  'Bakery',
#  'Tex-Mex, Mexican',
#  'Bar Food',
#  'Seafood, Brazilian',
#  'International',
#  'Pizza',
#  'Bar Food, Brazilian',
#  'French',
#  'Arabian, Brazilian, Pizza',
#  'Steak',
#  'German',
#  'Cafe, Brazilian',
#  'Brazilian, Grill',
#  'Sushi, Japanese',
#  'Brazilian, North Eastern',
#  'Japanese, Bar Food',
#  'Grill, Brazilian',
#  'Peruvian',
#  'Peruvian, Latin American',
#  'American, Grill',
#  'Seafood',
#  'Brazilian, Seafood',
#  'North Eastern, Bar Food',
#  'Ice Cream',
#  'Steak, Burger',
#  'Grill, American',
#  'American, International',
#  'Brazilian, Gourmet Fast Food, Healthy Food, Street Food',
#  'Italian, Fast Food',
#  'Burger, Fast Food',
#  'Mexican, Grill',
#  'Vegetarian, Healthy Food',
#  'Seafood, Bar Food, Brazilian',
#  'Steak, Brazilian',
#  'Brazilian, Steak',
#  'Contemporary',
#  'Japanese, Thai, Asian',
#  'Japanese, Contemporary',
#  'Desserts, Cafe',
#  'Brazilian, Bar Food',
#  'Juices, Healthy Food',
#  'Steak, Grill, Brazilian',
#  'Beverages, Bar Food, Fast Food',
#  'Seafood, International, Grill',
#  'Brazilian, Cafe',
#  'Arabian, Lebanese',
#  'Cafe, Bakery, Brazilian',
#  'Burger',
#  'Brazilian, Healthy Food, Juices, Pizza',
#  'Spanish',
#  'French, Author',
#  'Brazilian, Contemporary',
#  'Cafe, Bakery',
#  'Mexican',
#  'Brazilian, Grill, Seafood',
#  'Juices, Healthy Food, Burger',
#  'French, Steak',
#  'Thai',
#  'Italian, Contemporary',
#  'Healthy Food, Juices',
#  'Brazilian, Cafe, Healthy Food',
#  'American, Fast Food',
#  'Brazilian, North Eastern, Seafood',
#  'Steak, BBQ',
#  'Indian',
#  'Mineira, Brazilian',
#  'Beverages, International',
#  'French, Brazilian, Beverages',
#  'American, Mediterranean, Contemporary, Burger',
#  'BBQ, Steak',
#  'French, Contemporary, Steak',
#  'Vegetarian, Contemporary, Healthy Food',
#  'French, Italian, Brazilian',
#  'Mongolian, Grill',
#  'Portuguese',
#  'Spanish, Tapas',
#  'BBQ, Grill, Brazilian',
#  'Contemporary, Brazilian',
#  'Burger, Sandwich',
#  'BBQ',
#  'Greek',
#  'Asian, Japanese, Thai, Korean, Brazilian, Chinese',
#  'Brazilian, Fast Food',
#  'Sushi',
#  'French, Italian',
#  'Author, Fusion, Brazilian',
#  'Gourmet Fast Food, Burger',
#  'Brazilian, Beverages',
#  'Brazilian, Italian',
#  'Brazilian, Mineira',
#  'Beverages',
#  'Brazilian, Bar Food, Beverages',
#  'Lebanese, Arabian',
#  'Korean, Dumplings',
#  'Modern Australian',
#  'Desserts',
#  'American, Burger, Sandwich',
#  'African, BBQ',
#  'Asian, Thai',
#  'Coffee and Tea, Cafe Food',
#  'Asian, Vietnamese',
#  'Vegetarian, Coffee and Tea, Cafe Food',
#  'Australian, Desserts',
#  'Asian, Indian, Singaporean',
#  'Desserts, Coffee and Tea, Cafe Food',
#  'Desserts, Ice Cream, French',
#  'Middle Eastern, Afghan',
#  'Italian, Pizza, Seafood',
#  'Burger, Coffee and Tea, Cafe Food',
#  'German, Modern Australian',
#  'Modern Australian, Australian',
#  'BBQ, Japanese, Tapas',
#  'Argentine, Steak',
#  'French, Tapas',
#  'Latin American, Mexican',
#  'Malaysian, Thai, Vietnamese',
#  'Italian, Pizza, Bar Food',
#  'American, Bar Food',
#  'Asian, Middle Eastern, Modern Australian',
#  'Bakery, Patisserie',
#  'Healthy Food, Vegetarian, Coffee and Tea, Cafe Food',
#  'Burger, Modern Australian',
#  'American, Burger, Ice Cream',
#  'Coffee and Tea, Desserts',
#  'Seafood, Southern, Cajun',
#  'American, Pub Food',
#  'Steak, Seafood',
#  'Steak, Brazilian, Southern',
#  'Japanese, Seafood, Sushi',
#  'American, Diner',
#  'American, Steak',
#  'Filipino, International, Southern',
#  'American, Mexican, Southwestern',
#  'BBQ, Southern',
#  'American, Bar Food, Pub Food',
#  'BBQ, Southwestern',
#  'Seafood, Southern',
#  'Mexican, Southwestern',
#  'American, Sandwich',
#  'Tapas',
#  'International, New American',
#  'Italian, Seafood, Steak',
#  'American, Vegetarian, Southern',
#  'Seafood, Bar Food, Southern',
#  'American, Southern',
#  'New American',
#  'Pub Food',
#  'Burger, Bar Food',
#  'American, Breakfast',
#  'American, Mediterranean, Diner',
#  'Southern',
#  'American, Southern, BBQ',
#  'Bakery, Bagels, Donuts',
#  'Coffee and Tea, Bar Food',
#  'European, Bar Food',
#  'Fast Food, Burger, Salad',
#  'Bakery, Fast Food',
#  'Spanish, Cuban, Caribbean',
#  'American, Seafood',
#  'Burger, Desserts',
#  'Mexican, Southwestern, Tex-Mex',
#  'Coffee and Tea, Sandwich, Southern',
#  'American, Desserts, Burger',
#  'Diner, Tex-Mex',
#  'Seafood, Steak',
#  'Desserts, American',
#  'Tex-Mex, Southwestern, Mexican',
#  'American, Tex-Mex',
#  'Donuts, Bakery, American',
#  'American, Cafe',
#  'Cafe, American, Bar Food',
#  'Tex-Mex, Mexican, Taco',
#  'Southern, American',
#  'Tex-Mex, Diner, Mexican',
#  'Mexican, Seafood',
#  'Bar Food, American',
#  'Burger, American',
#  'Bakery, Cafe, Coffee and Tea',
#  'BBQ, American',
#  'New American, Southern',
#  'Southwestern',
#  'Desserts, Bakery, American',
#  'Burger, Southern, American',
#  'Spanish, Tex-Mex, Cafe',
#  'Seafood, Cajun',
#  'Sandwich',
#  'American, Mexican, Tex-Mex',
#  'French, Cafe',
#  'Mexican, Taco',
#  'Mexican, Tex-Mex',
#  'Pizza, Sandwich',
#  'Burger, Southwestern',
#  'Steak, New American',
#  'Mexican, American',
#  'Steak, American',
#  'American, Burger, Seafood',
#  'American, Desserts',
#  'American, Desserts, International',
#  'New American, Seafood',
#  'Cafe, American',
#  'Asian, Japanese, Sushi',
#  'European, French',
#  'Chinese, Dim Sum',
#  'Asian, Malaysian',
#  'BBQ, Italian, Pizza',
#  'Irish, Bar Food',
#  'American, Burger, Desserts',
#  'Mexican, Southern, Cajun',
#  'Mediterranean, Middle Eastern, Turkish',
#  'Sandwich, Vegetarian',
#  'Desserts, Bakery',
#  'European, Seafood',
#  'Italian, Seafood',
#  'Bakery, Cafe',
#  'Asian, Ramen',
#  'Vietnamese, Cafe Food, Salad',
#  'Contemporary, French',
#  'Cafe Food, Bar Food',
#  'Cafe Food, Coffee and Tea',
#  'Bakery, Coffee and Tea',
#  'Japanese, Cafe Food',
#  'Italian, Salad',
#  'Korean BBQ',
#  'Steak, Modern Australian',
#  'Cafe Food, Modern Australian',
#  'German, Pub Food',
#  'Healthy Food, Asian',
#  'Middle Eastern, Turkish',
#  'Middle Eastern',
#  'Japanese, Dumplings',
#  'American, BBQ, Salad',
#  'Cafe Food, French',
#  'Cafe Food',
#  'Cafe Food, Modern Australian, Coffee and Tea',
#  'Middle Eastern, Cafe Food, Salad',
#  'Seafood, Modern Australian',
#  'Asian, Japanese, Tapas',
#  'Italian, Korean, Fusion',
#  'Desserts, Modern Australian',
#  'Cafe Food, Burger, Tapas',
#  'Modern Australian, Cafe Food',
#  'Fusion, Coffee and Tea, Desserts, Cafe Food',
#  'Greek, Mediterranean, Salad',
#  'Mediterranean, Greek, Salad',
#  'Vietnamese, Chinese, Malaysian, Salad',
#  'Chinese, Vietnamese, Salad',
#  'Cafe Food, Modern European',
#  'Vegetarian, Desserts',
#  'Canadian',
#  'Korean, Tapas, Fusion',
#  'Desserts, Italian, Pizza',
#  'Seafood, Tapas, Fusion',
#  'Fast Food',
#  'Asian, Indian',
#  'Mediterranean, Middle Eastern',
#  'Desserts, French',
#  'Mexican, Fusion',
#  'German, Bar Food',
#  'Italian, Deli',
#  'BBQ, Korean',
#  'Breakfast, Sandwich',
#  'Breakfast, Burger',
#  'Asian, Beverages, Bubble Tea',
#  'Japanese, Sushi, Tapas, Ramen',
#  'Japanese, Sushi, Ramen',
#  'Asian, Chinese, Cafe',
#  'Desserts, Ice Cream',
#  'Breakfast, Italian, Fusion',
#  'Japanese, Sushi, Tapas',
#  'Brazilian, Latin American',
#  'Breakfast, Coffee and Tea',
#  'Burger, Pizza',
#  'Mediterranean, Deli, Kebab',
#  'Chinese, Malaysian',
#  'Steak, Fusion',
#  'Diner',
#  'Sushi, Ramen',
#  'European, French, Tapas',
#  'Japanese, Steak, Teriyaki',
#  'American, Sandwich, Burger',
#  'Asian, Sushi',
#  'Bakery, Desserts',
#  'American, Southern, Bar Food',
#  'Pizza, Eastern European',
#  'Cajun, Southern',
#  'Southern, Diner',
#  'Southern, Soul Food, BBQ',
#  'Tapas, Pub Food, American',
#  'Thai, Asian',
#  'American, Seafood, Steak',
#  'Bakery, Cafe, Desserts',
#  'Mexican, Southwestern, Caribbean',
#  'French, American, Pub Food',
#  'German, International',
#  'Tapas, Sushi, Bar Food',
#  'Greek, Italian',
#  'American, Fast Food, Southern',
#  'French, Bakery',
#  'BBQ, Burger',
#  'Burger, Sushi, Fusion',
#  'Seafood, Southern, New American',
#  'Diner, Desserts, American',
#  'Greek, Mediterranean',
#  'Italian, Pizza, Sandwich',
#  'Pizza, Italian, Sandwich',
#  'American, German',
#  'American, Southwestern, BBQ',
#  'Mediterranean, Tapas',
#  'American, Pizza, Burger, Sandwich',
#  'American, Italian, Burger, Sandwich',
#  'Seafood, Sushi',
#  'Peruvian, Japanese, Fusion',
#  'Italian, Steak, American',
#  'Pizza, American',
#  'Japanese, Steak, Sushi',
#  'Asian',
#  'New Mexican',
#  'Belgian, American',
#  'Seafood, New American',
#  'Mediterranean',
#  'Cuban, Mexican, Latin American',
#  'New American, Bakery',
#  'Pizza, Bar Food',
#  'American, French',
#  'Tex-Mex',
#  'Taco, Tex-Mex',
#  'American, BBQ',
#  'Diner, Vegetarian',
#  'Fast Food, Seafood',
#  'American, Italian, Pizza',
#  'Steak, Seafood, Sushi',
#  'American, Bakery',
#  'New American, Sushi, Seafood, Steak',
#  'Latin American, Cafe',
#  'Thai, Vietnamese',
#  'Italian, Sandwich',
#  'Taco, New American',
#  'Cafe, Sandwich',
#  'Indian, Mediterranean',
#  'New American, Pub Food',
#  'Asian, Fusion, New American, Sushi',
#  'Asian, Chinese',
#  'American, Coffee and Tea',
#  'Asian, Fusion',
#  'Greek, American',
#  'American, Burger, Mexican',
#  'Burger, American, Steak',
#  'American, Burger, Bar Food',
#  'New American, Desserts',
#  'Cafe, Cajun',
#  'American, Tapas',
#  'American, Asian, European',
#  'Middle Eastern, Mediterranean',
#  'Breakfast',
#  'Cuban, Sandwich, Southwestern',
#  'American, International, Bar Food',
#  'Mediterranean, Middle Eastern, Vegetarian',
#  'American, Vegetarian',
#  'American, BBQ, Southern',
#  'Breakfast, Coffee and Tea, Mediterranean',
#  'Vegetarian',
#  'American, Breakfast, Southern',
#  'American, Burger, Fast Food',
#  'American, BBQ, Southwestern',
#  'Japanese, Korean, Sushi',
#  'Burger, Sandwich, Bar Food',
#  'Desserts, Mediterranean',
#  'Caribbean, Cuban',
#  'Seafood, Steak, Cajun',
#  'Breakfast, Burger, Sandwich',
#  'American, BBQ, Cajun',
#  'Breakfast, Diner, Sandwich',
#  'Polish, Cafe',
#  'Burger, Diner',
#  'Burger, Vegetarian, California',
#  'Middle Eastern, Vegetarian',
#  'Breakfast, Vegetarian',
#  'European, Polish',
#  'Japanese, Sushi, Thai',
#  'Burger, Vegetarian',
#  'American, BBQ, Sandwich',
#  'American, Burger, Steak',
#  'International, Seafood, Steak',
#  'Deli',
#  'American, Breakfast, Vegetarian',
#  'Greek, Seafood, Cajun',
#  'Seafood, Healthy Food',
#  'Burger, Seafood',
#  'Steak, Cajun',
#  'Seafood, American',
#  'Mediterranean, Greek',
#  'Fusion, International',
#  'British, Bar Food',
#  'Italian, Sandwich, Seafood',
#  'Tapas, Spanish',
#  'Taco',
#  'Southern, French',
#  'American, Indian',
#  'Asian, Latin American, Sushi',
#  'Cajun, Seafood',
#  'Desserts, Diner',
#  'African',
#  'European, Mediterranean',
#  nan,
#  'Asian, Burger',
#  'Breakfast, French',
#  'Breakfast, Diner, Bar Food',
#  'California',
#  'Italian, Steak',
#  'European',
#  'Mexican, Tapas',
#  'Asian, International',
#  'Southern, Steak',
#  'European, Steak',
#  'French, Seafood',
#  'Pizza, California',
#  'Breakfast, International',
#  'Asian, Thai, Vegetarian',
#  'Bakery, American, Desserts',
#  'American, California',
#  'American, Breakfast, Diner',
#  'American, European, Steak',
#  'French, Italian, Spanish',
#  'Breakfast, Coffee and Tea, Tapas',
#  'American, Deli',
#  'Asian, California',
#  'Breakfast, Sandwich, Deli',
#  'Italian, California',
#  'Breakfast, Diner',
#  'Brazilian, Latin American, Pizza',
#  'American, Breakfast, Coffee and Tea',
#  'Italian, Vegetarian',
#  'Cuban',
#  'Coffee and Tea, Tea',
#  'Bar Food, Steak',
#  'Seafood, Latin American, Mexican',
#  'Latin American, Burger, Sandwich, Vegetarian, New American',
#  'American, International, Vegetarian, New American',
#  'Mediterranean, Greek, Vegetarian',
#  'Fast Food, Burger',
#  'Seafood, Bar Food, Sandwich',
#  'American, Pizza, Sandwich',
#  'American, New American',
#  'Seafood, Burger, Southern, Cajun, Creole',
#  'American, Seafood, Burger',
#  'Sandwich, Seafood, Floribbean',
#  'Mexican, Latin American, Floribbean',
#  'BBQ, Sandwich, Southern',
#  'Latin American, Cuban',
#  'Seafood, Thai, Steak',
#  'American, Asian, Burger',
#  'Fast Food, Sandwich, Salad',
#  'American, Latin American, Floribbean',
#  'Coffee and Tea, Breakfast, Sandwich',
#  'Cafe, French, Crepes',
#  'Japanese, Seafood, Brazilian, Peruvian, Sushi',
#  'Japanese, Seafood, Spanish, Sushi, Tapas, Vegetarian, South American, New American',
#  'Breakfast, Desserts, Crepes',
#  'Asian, BBQ, Japanese',
#  'Japanese, Bar Food, Tapas',
#  'French, Canadian',
#  'Seafood, Portuguese',
#  'Indian, Vegetarian',
#  'Desserts, Steak, Deli',
#  'French, British',
#  'Fast Food, British, Fish and Chips',
#  'French, Spanish',
#  'American, French, Italian',
#  'Greek, Mediterranean, Seafood',
#  'Healthy Food, Beverages, Vegetarian',
#  'Others',
#  'Diner, Canadian',
#  'BBQ, Portuguese',
#  'Eastern European, Deli',
#  'Coffee and Tea, Fast Food',
#  'Southern, Tex-Mex',
#  'Bar Food, Canadian',
#  'International, Seafood',
#  'Breakfast, Bar Food',
#  'Asian, Malaysian, Thai',
#  "Sandwich, Po'Boys",
#  'Breakfast, Seafood, Southern',
#  'Southern, Cajun',
#  'Seafood, French',
#  'American, French, International',
#  "Seafood, Cajun, Po'Boys",
#  'Coffee and Tea, Cafe',
#  'Breakfast, French, Cajun',
#  'French, Southern, Cajun',
#  'BBQ, Seafood, Cajun',
#  'Creole, Cajun',
#  'Bar Food, Southern',
#  'American, Seafood, Cajun',
#  'French, Seafood, Southern',
#  "Breakfast, Southern, Po'Boys",
#  'American, Italian, Southern',
#  'American, Southern, Cajun',
#  'Burger, Bar Food, Steak',
#  'American, Breakfast, Cajun',
#  "Vegetarian, Cajun, Po'Boys",
#  'Caribbean, Sandwich',
#  'American, French, Southern',
#  'Breakfast, Cajun',
#  "Southern, Cajun, Po'Boys",
#  'French, Italian, Southern',
#  'French, Vegetarian',
#  'Sandwich, Southern',
#  'BBQ, Southern, Cajun',
#  'Chinese, Fusion, Asian',
#  'American, Italian',
#  'Latin American, Venezuelan',
#  'Ramen',
#  'Ukrainian',
#  'Cuban, Mexican',
#  'BBQ, American, Southern',
#  'New American, French',
#  'Bakery, Desserts, Sandwich',
#  'European, Belgian',
#  'American, Burger, Sushi',
#  'Donuts',
#  'Seafood, Bagels',
#  'American, Italian, Sandwich',
#  'American, Bakery, Desserts',
#  'Middle Eastern, Moroccan',
#  'French, Seafood, Bakery',
#  'Steak, American, German, Burger',
#  'French, European',
#  'American, Juices, Beverages',
#  'Mediterranean, Desserts, Bar Food',
#  'Italian, Southern',
#  'Mexican, Vegetarian',
#  'Burger, Canadian',
#  'BBQ, Burger, Southern',
#  'Italian, Canadian',
#  'Canadian, Southern',
#  'Italian, Bar Food',
#  'Sandwich, Bakery',
#  'Canadian, Fusion',
#  'Pizza, Canadian',
#  'Ice Cream, Desserts, Cafe',
#  'Canadian, European, Asian',
#  'Bakery, Sandwich',
#  'Canadian, Tapas',
#  'Canadian, American',
#  'French, Seafood, Canadian',
#  'Seafood, Canadian',
#  'Canadian, Diner',
#  'Canadian, International',
#  'Hawaiian, Japanese',
#  'Sandwich, Coffee and Tea, Cafe Food',
#  'Malaysian',
#  'Australian',
#  'Mexican, Coffee and Tea, Cafe Food',
#  'Coffee and Tea, Sandwich, Cafe Food',
#  'Middle Eastern, Cafe Food',
#  'Italian, Mediterranean',
#  'Mediterranean, Bakery',
#  'Bar Food, Modern Australian',
#  'Healthy Food, Pizza, Cafe Food',
#  'Coffee and Tea, Modern Australian, Cafe Food',
#  'Patisserie, Cafe Food',
#  'Asian, Bar Food',
#  'Mediterranean, Middle Eastern, Tapas',
#  'Yum Cha, Chinese',
#  'Malaysian, Asian',
#  'Mexican, Bar Food',
#  'Desserts, Coffee and Tea',
#  'Korean, BBQ',
#  'European, Modern Australian',
#  'Greek, Tapas, Mediterranean',
#  'Modern Australian, European',
#  'Beverages, Cafe Food',
#  'Desserts, Cafe Food',
#  'Modern Australian, Cafe Food, Coffee and Tea',
#  'Chinese, Asian',
#  'Diner, American',
#  'New American, Bar Food',
#  'Ice Cream, Desserts',
#  'Cuban, Latin American',
#  'Belgian, European, Bar Food',
#  'Sandwich, Fast Food',
#  'Sandwich, American',
#  'Belgian, Bar Food',
#  'French, American',
#  'European, International, Asian',
#  'British',
#  'American, Mediterranean',
#  'Cafe, Pizza',
#  'Bar Food, Seafood',
#  'Mediterranean, Italian',
#  'Cuban, Latin American, Spanish',
#  'Fast Food, Sandwich',
#  'Desserts, Juices, Healthy Food',
#  'American, Steak, Bar Food',
#  'American, Breakfast, Sandwich',
#  'Breakfast, Mexican',
#  'Southwestern, Bar Food',
#  'American, Sushi',
#  'Cafe, Sandwich, Sushi',
#  'Healthy Food, Vegetarian',
#  'American, Southwestern',
#  'Caribbean, Chinese, Mexican',
#  'Bar Food, Sandwich',
#  'Mediterranean, Sandwich, Vegetarian',
#  'Pizza, Italian, Healthy Food',
#  'Caribbean, Seafood',
#  'Japanese, Italian, Sushi',
#  'Hawaiian, Asian, New American, American',
#  'Coffee and Tea, Sandwich',
#  'Italian, Pizza, Healthy Food',
#  'New American, Healthy Food',
#  'European, New American',
#  'Healthy Food, Diner, Sandwich',
#  'French, Bakery, Desserts',
#  'American, Coffee and Tea, Southern',
#  'BBQ, Breakfast, Southern',
#  'Taco, Mexican',
#  'Latin American, Spanish, Tapas',
#  'Cajun, Soul Food',
#  'Greek, Mediterranean, Middle Eastern',
#  'European, Italian, Pizza',
#  'American, Pacific Northwest',
#  'Asian, Chinese, Japanese',
#  'Breakfast, Vegetarian, Donuts',
#  'Pacific Northwest',
#  'Seafood, Pacific Northwest',
#  'Asian, Seafood, Steak',
#  'Pacific Northwest, Steak',
#  'BBQ, Burger, Bar Food',
#  'Lebanese, Middle Eastern, Vegetarian',
#  'American, Breakfast, Desserts',
#  'American, Breakfast, Pacific Northwest',
#  'Latin American, Tapas, Peruvian',
#  'Mexican, Latin American',
#  'Latin American, Mexican, Tapas',
#  'Caribbean, Hawaiian',
#  'Italian, Mediterranean, Seafood',
#  'Seafood, Steak, American',
#  'Steak, Seafood, American',
#  'Tea, Cafe',
#  'Sushi, Asian, American',
#  'Bakery, American',
#  'Moroccan',
#  'Chinese, Sushi',
#  'Southwestern, Steak',
#  'German, Sandwich, Deli',
#  'American, Mediterranean, International',
#  'French, Belgian',
#  'American, Latin American, California',
#  'Asian, Chinese, Vegetarian',
#  'Vegetarian, California',
#  'Middle Eastern, American',
#  'Breakfast, European, French',
#  'California, Seafood',
#  'American, Breakfast, California',
#  'California, New American',
#  'International, Healthy Food',
#  'American, Mexican',
#  'Bar Food, Seafood, California',
#  'Diner, California',
#  'Cafe, Mexican',
#  'American, Vegetarian, Healthy Food',
#  'Mexican, Seafood, Vegetarian',
#  'Seafood, Chinese',
#  'Italian, French, California',
#  'Hawaiian, Fusion',
#  'Vietnamese, Fusion',
#  'Seafood, Italian',
#  'Burger, Pizza, American',
#  'American, Seafood, Bakery',
#  'Ice Cream, Coffee and Tea',
#  'Cuban, Tapas, Caribbean',
#  'Burmese',
#  'Seafood, International',
#  'Spanish, American, Tapas',
#  'Dim Sum, Chinese',
#  'Crepes, Cafe',
#  'California, Fusion',
#  'Pacific Northwest, Seafood, Tapas',
#  'Caribbean, Latin American, Cajun',
#  'Pacific Northwest, Seafood',
#  'Cafe, French',
#  'Pub Food, American',
#  'Burger, Diner, American',
#  'Sushi, Japanese, Latin American',
#  'Sandwich, Deli, Italian',
#  'International, Desserts',
#  'Fish and Chips, Pacific Northwest, Seafood',
#  'Pacific Northwest, American',
#  'Donuts, Coffee and Tea',
#  'Vietnamese, Chinese, Asian',
#  'Caribbean, Sandwich, Cuban',
#  'Korean, Fusion',
#  'Greek, Mediterranean, Pacific Northwest',
#  'Vegetarian, Breakfast',
#  'Cafe, French, Bakery',
#  'Russian, Bakery',
#  'Sandwich, Cafe',
#  'Fish and Chips, Seafood, Pacific Northwest',
#  'Cajun, French',
#  'Burger, Sandwich, Beverages',
#  'Vegetarian, Mediterranean, Indian',
#  'Pacific Northwest, New American',
#  'Bakery, French, Desserts',
#  'Bakery, Ice Cream, Desserts',
#  'Singaporean, Chinese, Asian',
#  'Continental, Spanish',
#  'South Indian, Singaporean, Middle Eastern, Indian',
#  'American, Asian, Continental, Fusion',
#  'Chinese, Continental, Singaporean',
#  'French, Continental',
#  'North Indian, Indian, South Indian, American',
#  'Asian, French, Fusion',
#  'Continental, European, Steak',
#  'European, Middle Eastern',
#  'French, Mediterranean, European',
#  'Continental, Bar Food',
#  'Continental, French',
#  'Chinese, French, Japanese',
#  'Singaporean, Chinese',
#  'Mediterranean, Asian, Japanese, Sushi, Seafood, French',
#  'European, Spanish, American, Cafe',
#  'European, Seafood, Australian, Steak',
#  'Cafe, French, Bakery, Italian',
#  'American, Japanese, Singaporean',
#  'South Indian, North Indian',
#  'Asian, Continental, Seafood, Bakery',
#  'Chinese, Thai, Japanese, Italian',
#  'Singaporean, Chinese, Seafood, Malay, Indian',
#  'Chinese, Seafood, Cantonese, Dim Sum',
#  'Singaporean, European, Seafood, Indian, Japanese, Continental',
#  'Asian, Japanese, Seafood, Singaporean, Chinese',
#  'Singaporean, Chinese, Dim Sum, Healthy Food, Seafood, Cantonese',
#  'American, Continental, Italian, Pizza, Steak',
#  'Singaporean, Australian, German',
#  'American, Cafe, Italian',
#  'Cafe, Fusion, Western',
#  'Japanese, Continental, Sushi, Fusion',
#  'Cafe, Bakery, Desserts',
#  'Italian, Australian, Healthy Food, Fusion',
#  'Indian, North Indian, South Indian',
#  'Continental, Indian, Asian',
#  'Salad, Healthy Food, Western, Cafe',
#  'American, Bakery, European, Burger, Fusion',
#  'American, European, Singaporean',
#  'Singaporean, Chinese, Seafood',
#  'Italian, European',
#  'American, European, Australian, Steak',
#  'Finger Food',
#  'Continental, European',
#  'American, Continental, French, Seafood',
#  'Finger Food, Burger, Fast Food',
#  'Singaporean, Seafood, BBQ',
#  'Middle Eastern, Sandwich, Vegetarian',
#  'European, Bar Food, Belgian',
#  'American, Pizza',
#  'European, Tapas, Eastern European',
#  'American, Burger, Pizza',
#  'African, Portuguese',
#  'Greek, Mediterranean, Turkish',
#  'Asian, Dim Sum',
#  'European, French, Seafood',
#  'American, Breakfast, Seafood',
#  'American, Seafood, Bar Food',
#  'American, Southern, Jamaican',
#  'Italian, Mediterranean, Pizza',
#  'Mexican, Spanish, Tex-Mex',
#  'American, Seafood, Sushi',
#  'American, Desserts, Bar Food',
#  'Desserts, Bar Food',
#  'Coffee and Tea',
#  'American, Breakfast, Bar Food',
#  'American, Mediterranean, Vegetarian',
#  'American, Bar Food, Seafood',
#  'Cafe, European, American, Salad, Healthy Food, Continental',
#  'Mandi, Emirati, Arabian, Middle Eastern',
#  'Turkish, Arabian, Middle Eastern',
#  'Indian, Mughlai',
#  'Japanese, Sushi, Salad',
#  'Sushi, Japanese, Asian',
#  'Lebanese, Arabian, Middle Eastern, Salad',
#  'Pizza, Fast Food',
#  'South Indian, North Indian, Chinese, Seafood',
#  'Indian, North Indian, Mughlai, Biryani, Chinese, Seafood',
#  'Indian, Mughlai, Chinese',
#  'Indian, Pakistani',
#  'Indian, Biryani, Hyderabadi',
#  'Indian, North Indian',
#  'Cafe, Healthy Food, Burger, Salad',
#  'Healthy Food, Salad, International',
#  'Indian, North Indian, South Indian, Chinese',
#  'Burger, Fast Food, Portuguese, African',
#  'Indian, North Indian, Mughlai, Biryani',
#  'Indian, BBQ',
#  'Lebanese',
#  'Thai, Asian, Chinese',
#  'American, Mexican, Seafood',
#  'Indian, North Indian, Mughlai, Biryani, Kebab',
#  'Indian, North Indian, Chinese, Healthy Food',
#  'Indian, South Indian',
#  'Chinese, Indian, North Indian, Kerala, Mughlai, South Indian',
#  'Kerala',
#  'North Indian, Mughlai, Biryani, Indian',
#  'Pakistani, Indian, Hyderabadi, Afghan',
#  'Indian, Kerala, Biryani',
#  'Indian, North Indian, South Indian, Street Food, Desserts',
#  'Thai, Asian, Chinese, Indian, Japanese, Sushi',
#  'Lebanese, Arabian, Middle Eastern',
#  'American, Mexican, Tex-Mex, Steak, Salad',
#  'Indian, Chinese',
#  'Lebanese, Salad',
#  'Indian, North Indian, Chinese',
#  'Portuguese, African',
#  'Healthy Food, American',
#  'Indian, Biryani',
#  'Indian, Street Food, Chinese, North Indian, Fast Food, Burger, Beverages, Sandwich',
#  'Chinese, Seafood',
#  'Indian, South Indian, Chinese',
#  'Italian, Pizza, Salad',
#  'American, Desserts, Salad',
#  'Indian, Biryani, Mughlai',
#  'Indian, BBQ, Continental',
#  'Indian, North Indian, Rajasthani',
#  'Indian, Gujarati, Rajasthani',
#  'Indian, Chinese, Grill, Kebab',
#  'Indian, North Indian, Street Food, Fast Food',
#  'Chinese, Asian, Street Food',
#  'Cafe, Indian, Street Food',
#  'Indian, North Indian, Chinese, Street Food',
#  'Indian, Street Food',
#  'Indian, North Indian, Kebab',
#  'Indian, Mughlai, North Indian, Kebab',
#  'Indian, Biryani, Kebab, North Indian',
#  'Indian, Fast Food, Street Food, Chinese',
#  'Indian, North Indian, Healthy Food',
#  'Biryani, North Indian, Pakistani, Mughlai, Afghan, Indian, Kebab',
#  'Kerala, South Indian, Indian',
#  'Arabian, Middle Eastern, Salad, Kebab',
#  'Biryani, Hyderabadi, North Indian',
#  'North Indian, Lebanese, Chinese, Kebab',
#  'Indian, Chinese, Kebab',
#  'Cafe, Arabian, Middle Eastern, Lebanese',
#  'Indian, BBQ, Kebab',
#  'Indian, Contemporary',
#  'Steak, Continental, North Indian',
#  'Asian, Thai, Seafood, Chinese',
#  'Chinese, Japanese, Asian',
#  'Mexican, Peruvian, Latin American',
#  'Contemporary, Indian',
#  'Indian, North Indian, Contemporary',
#  'Healthy Food, Poké',
#  'Mediterranean, Pizza, Middle Eastern',
#  'Belgian, Finger Food, European',
#  'Indian, International',
#  'Biryani, North Indian, Mughlai, Indian',
#  'Indian, Arabian, Middle Eastern, Italian, Pizza',
#  'Street Food, Arabian, Middle Eastern, Salad',
#  'British, Asian, Arabian, Middle Eastern',
#  'Lebanese, Turkish',
#  'North Indian, Street Food, Chinese, Desserts, Ice Cream',
#  'Nepalese, Japanese, Fast Food, Sushi',
#  'Kerala, South Indian',
#  'Sushi, American, Seafood',
#  'Arabian, Middle Eastern, Salad',
#  'Japanese, Seafood, Italian, Beverages',
#  'Asian, Thai, Chinese',
#  'Lebanese, Arabian, Salad',
#  'Goan, Chinese, Indian, North Indian',
#  'Filipino, Japanese, Asian',
#  'Indian, European',
#  'Asian, Mediterranean',
#  'Lebanese, Chinese, South Indian, Mughlai',
#  'Indian, Fast Food',
#  'American, Japanese, Mexican',
#  'Turkish',
#  'Indian, South Indian, North Indian',
#  'Cafe, Arabian, Desserts',
#  'Iranian',
#  'Pakistani, Afghan',
#  'Arabian, Middle Eastern, Seafood',
#  'Malaysian, Thai, Indonesian',
#  'Arabian, Middle Eastern, Italian, Indian',
#  'Indian, Chinese, Arabian, Middle Eastern, Bakery',
#  'Pakistani',
#  'Irish',
#  'American, Mexican, Burger',
#  'Arabian, Middle Eastern, Asian, American, Steak, Indian, Desserts',
#  'Arabian, Middle Eastern',
#  'Italian, Arabian, Middle Eastern, Seafood',
#  'Continental, American, Arabian, Middle Eastern, Italian, Indian, Healthy Food',
#  'Arabian, Middle Eastern, Mediterranean',
#  'Arabian, Middle Eastern, Italian, European, Indian',
#  'Continental',
#  'Indian, North Indian, Mughlai',
#  'South Indian',
#  'Fast Food, Burger, American',
#  'Pakistani, Indian, Chinese',
#  'Indian, South Indian, Bengali',
#  'Indian, Kerala',
#  'Chinese, Indian, North Indian',
#  'Indian, Arabian, Middle Eastern',
#  'Street Food, North Indian, Indian',
#  'Indian, Mughlai, North Indian, Biryani, Kebab',
#  'Indian, Chinese, South Indian',
#  'Mughlai, Indian, Pakistani',
#  'Fast Food, Juices',
#  'Mandi, Arabian, Middle Eastern, Yemeni',
#  'North Indian, Chinese, Hyderabadi',
#  'Chinese, South Indian, Indian',
#  'Fast Food, Arabian, Middle Eastern',
#  'Burger, Fast Food, Street Food',
#  'Indian, North Indian, South Indian, Fast Food',
#  'Indian, North Indian, Seafood, Continental',
#  'Pakistani, Indian',
#  'Lebanese, Middle Eastern, Arabian',
#  'Chinese, Indian, Kerala',
#  'Pakistani, Indian, Mughlai, Desserts',
#  'Pakistani, Chinese, Indian, Afghan',
#  'Indian, Pakistani, Fast Food',
#  'Indian, South Indian, Chinese, Fast Food',
#  'Indian, South Indian, North Indian, Chinese',
#  'Fast Food, Pizza',
#  'Indian, Chinese, Mughlai',
#  'Chinese, North Indian, Mughlai',
#  'Chinese, Indian',
#  'Indian, North Indian, Fast Food',
#  'Fast Food, Indian, Nepalese, Burger, Pizza, Chinese',
#  'Indian, Seafood, Pakistani, Grill',
#  'Fast Food, Lebanese',
#  'South Indian, Kerala',
#  'Chinese, Indian, Nepalese',
#  'Chinese, Thai',
#  'Indian, North Indian, Street Food',
#  'Indian, North Indian, Desserts',
#  'Indian, American, Asian, Fast Food',
#  'North Indian, Mughlai',
#  'Street Food',
#  'North Indian, Mughlai, Rolls, Chinese, Fast Food, Street Food',
#  'North Indian, Continental, Chinese',
#  'North Indian, Chinese, Mughlai',
#  'North Indian',
#  'North Indian, South Indian, Chinese, Bakery, Momos',
#  'Bakery, Desserts, Sandwich, Burger, Pizza, Fast Food',
#  'Desserts, Bakery, Fast Food, South Indian',
#  'Tea, Fast Food',
#  'Rajasthani',
#  'Continental, North Indian, Chinese',
#  'Burger, Sandwich, Fast Food, Pizza, Rolls, Bakery',
#  'South Indian, Chinese, Fast Food, Street Food, Mithai, Bakery',
#  'North Indian, Fast Food, Chinese, South Indian',
#  ...]

# %% [markdown]
# # 1.6. Treat NA

# %%
df1 = df1.dropna()
df1.isna().sum()
# Out:
# restaurant_id           0
# restaurant_name         0
# country_code            0
# city                    0
# address                 0
# locality                0
# locality_verbose        0
# longitude               0
# latitude                0
# cuisines                0
# average_cost_for_two    0
# currency                0
# has_table_booking       0
# has_online_delivery     0
# is_delivering_now       0
# switch_to_order_menu    0
# price_range             0
# aggregate_rating        0
# rating_color            0
# rating_text             0
# votes                   0
# dtype: int64

# %% [markdown]
# # 1.7. Change Types

# %% [markdown]
# Não há a necessidade de fazer a troca de tipos dos dados.

# %% [markdown]
# # 1.8. Descriptive Statistics

# %%
numerical_data = get_numerical_attributes(df1)

# %% [markdown]
# # 1.8.1. Numerical Data

# %%
get_first_order_statistics(numerical_data)
# Out:
#               attributes         min           max         range  \
# 0          restaurant_id  549.000000  1.904028e+07  1.903973e+07
# 1           country_code    1.000000  2.160000e+02  2.150000e+02
# 2              longitude -122.700455  1.753106e+02  2.980110e+02
# 3               latitude  -41.330428  5.597698e+01  9.730741e+01
# 4   average_cost_for_two    0.000000  2.500002e+07  2.500002e+07
# 5      has_table_booking    0.000000  1.000000e+00  1.000000e+00
# 6    has_online_delivery    0.000000  1.000000e+00  1.000000e+00
# 7      is_delivering_now    0.000000  1.000000e+00  1.000000e+00
# 8   switch_to_order_menu    0.000000  0.000000e+00  0.000000e+00
# 9            price_range    1.000000  4.000000e+00  3.000000e+00
# 10      aggregate_rating    0.000000  4.900000e+00  4.900000e+00
# 11                 votes    0.000000  4.133300e+04  4.133300e+04
#
#             mean        median           std       skew     kurtosis
# 0   1.054327e+07  7.701329e+06  7.075017e+06  -0.084078    -1.726900
# 1   9.313472e+01  3.000000e+01  9.902019e+01   0.257296    -1.849704
# 2   3.376321e+01  7.378280e+01  7.736959e+01  -0.679659    -0.596239
# 3   1.931223e+01  2.523716e+01  2.327263e+01  -1.080186     0.608968
# 4   7.165669e+03  2.900000e+02  2.908773e+05  84.494674  7257.443719
# 5   6.230032e-02  0.000000e+00  2.417002e-01   3.622563    11.125924
# 6   3.531683e-01  0.000000e+00  4.779544e-01   0.614540    -1.622773
# 7   1.746539e-01  0.000000e+00  3.796708e-01   1.714175     0.938646
# 8   0.000000e+00  0.000000e+00  0.000000e+00   0.000000     0.000000
# 9   2.625399e+00  3.000000e+00  9.595017e-01  -0.041458    -0.982738
# 10  4.122724e+00  4.200000e+00  6.671262e-01  -3.898638    21.116355
# 11  6.174834e+02  3.350000e+02  1.128466e+03  10.662986   260.457206

# %% [markdown]
# # 2. ANSWERS

# %%
df2 = process_data(RAW_DATA_PATH)
df2
# Out:
#       restaurant_id                    restaurant_name      country  \
# 0           6310675         Mama Lou's Italian Kitchen  Philippines
# 1           6314542                          Blackbird  Philippines
# 2           6301293                           Banapple  Philippines
# 3           6315689                           Bad Bird  Philippines
# 4           6304833                              Manam  Philippines
# ...             ...                                ...          ...
# 6924        5912546                             Eataly       Turkey
# 6925        5913006  Tarihi Çınaraltı Aile Çay Bahçesi       Turkey
# 6926        5923535             Boon Cafe & Restaurant       Turkey
# 6927        5914190                   Kanaat Lokantası       Turkey
# 6928        5913508                            Katibim       Turkey
#
#                 city                                            address  \
# 0     Las Piñas City  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 1        Makati City  Nielson Tower, Ayala Triangle Gardens, Salcedo...
# 2        Makati City  Ayala Triangle Gardens, Salcedo Village, Makat...
# 3        Makati City  Hole In The Wall, Floor 4, Century City Mall, ...
# 4        Makati City  Level 1, Greenbelt 2, Ayala Center, Greenbelt,...
# ...              ...                                                ...
# 6924        İstanbul  Zorlu Center AVM, Köprü Katı, Levazım Mahalles...
# 6925        İstanbul  Çengelköy Mahallesi, Çınaraltı Camii Sokak, No...
# 6926        İstanbul  Çengelköy Mahallesi, Çengelköy Caddesi, Kara S...
# 6927        İstanbul  Sultantepe Mahallesi, Selmani Pak Caddesi, No ...
# 6928        İstanbul  Mimar Sinan Mahallesi, Harem Sahilyolu, No 53,...
#
#                                                locality  \
# 0                                      BF International
# 1     Ayala Triangle Gardens, Salcedo Village, Makat...
# 2     Ayala Triangle Gardens, Salcedo Village, Makat...
# 3             Century City Mall, Poblacion, Makati City
# 4                 Greenbelt 2, San Lorenzo, Makati City
# ...                                                 ...
# 6924                Zorlu Center AVM, Levazım, Beşiktaş
# 6925                                   Çengelköy Merkez
# 6926                                   Çengelköy Merkez
# 6927                                     Üsküdar Merkez
# 6928                                     Üsküdar Merkez
#
#                                        locality_verbose   longitude  \
# 0                      BF International, Las Piñas City  121.009787
# 1     Ayala Triangle Gardens, Salcedo Village, Makat...  121.024562
# 2     Ayala Triangle Gardens, Salcedo Village, Makat...  121.023171
# 3     Century City Mall, Poblacion, Makati City, Mak...  121.027708
# 4     Greenbelt 2, San Lorenzo, Makati City, Makati ...  121.020380
# ...                                                 ...         ...
# 6924      Zorlu Center AVM, Levazım, Beşiktaş, İstanbul   29.017326
# 6925                         Çengelköy Merkez, İstanbul   29.052620
# 6926                         Çengelköy Merkez, İstanbul   29.052623
# 6927                           Üsküdar Merkez, İstanbul   29.016590
# 6928                           Üsküdar Merkez, İstanbul   29.010808
#
#        latitude         cuisines price_type  average_cost_for_two  \
# 0     14.447615          Italian  expensive                  1100
# 1     14.556042         European    gourmet                  3100
# 2     14.556196         Filipino  expensive                   800
# 3     14.565899         American  expensive                   700
# 4     14.552351         Filipino  expensive                   700
# ...         ...              ...        ...                   ...
# 6924  41.065322          Italian    gourmet                   300
# 6925  41.050280        Fast Food     normal                    45
# 6926  41.050717  Restaurant Cafe    gourmet                   140
# 6927  41.025741        Home-made  expensive                    95
# 6928  41.025501  Restaurant Cafe    gourmet                   150
#
#               currency  has_table_booking  has_online_delivery  \
# 0     Botswana Pula(P)                  1                    0
# 1     Botswana Pula(P)                  0                    0
# 2     Botswana Pula(P)                  0                    0
# 3     Botswana Pula(P)                  0                    0
# 4     Botswana Pula(P)                  0                    0
# ...                ...                ...                  ...
# 6924  Turkish Lira(TL)                  0                    0
# 6925  Turkish Lira(TL)                  0                    0
# 6926  Turkish Lira(TL)                  0                    0
# 6927  Turkish Lira(TL)                  0                    0
# 6928  Turkish Lira(TL)                  0                    0
#
#       is_delivering_now  aggregate_rating rating_color color_name rating_text  \
# 0                     0               4.6       3F7E00  darkgreen   Excellent
# 1                     0               4.7       3F7E00  darkgreen   Excellent
# 2                     0               4.4       5BA829      green   Very Good
# 3                     0               4.4       5BA829      green   Very Good
# 4                     0               4.7       3F7E00  darkgreen   Excellent
# ...                 ...               ...          ...        ...         ...
# 6924                  0               4.3       5BA829      green   Very Good
# 6925                  0               4.5       3F7E00  darkgreen   Excellent
# 6926                  0               4.2       5BA829      green   Very Good
# 6927                  0               4.0       5BA829      green   Very Good
# 6928                  0               4.2       5BA829      green   Very Good
#
#       votes
# 0       619
# 1       469
# 2       867
# 3       858
# 4       930
# ...     ...
# 6924   1367
# 6925   1172
# 6926   1160
# 6927    770
# 6928   1141
#
# [6929 rows x 21 columns]

# %% [markdown]
# # Geral

# %% [markdown]
# ## 1. Quantos restaurantes únicos estão registrados?

# %%
df2_copy = df2.copy()
df2_copy.loc[:,'cuisines'].unique().tolist()
# Out:
# ['Italian',
#  'European',
#  'Filipino',
#  'American',
#  'Korean',
#  'Pizza',
#  'Taiwanese',
#  'Japanese',
#  'Coffee',
#  'Chinese',
#  'Seafood',
#  'Singaporean',
#  'Vietnamese',
#  'Latin American',
#  'Healthy Food',
#  'Cafe',
#  'Fast Food',
#  'Brazilian',
#  'Argentine',
#  'Arabian',
#  'Bakery',
#  'Tex-Mex',
#  'Bar Food',
#  'International',
#  'French',
#  'Steak',
#  'German',
#  'Sushi',
#  'Grill',
#  'Peruvian',
#  'North Eastern',
#  'Ice Cream',
#  'Burger',
#  'Mexican',
#  'Vegetarian',
#  'Contemporary',
#  'Desserts',
#  'Juices',
#  'Beverages',
#  'Spanish',
#  'Thai',
#  'Indian',
#  'Mineira',
#  'BBQ',
#  'Mongolian',
#  'Portuguese',
#  'Greek',
#  'Asian',
#  'Author',
#  'Gourmet Fast Food',
#  'Lebanese',
#  'Modern Australian',
#  'African',
#  'Coffee and Tea',
#  'Australian',
#  'Middle Eastern',
#  'Malaysian',
#  'Tapas',
#  'New American',
#  'Pub Food',
#  'Southern',
#  'Diner',
#  'Donuts',
#  'Southwestern',
#  'Sandwich',
#  'Irish',
#  'Mediterranean',
#  'Cafe Food',
#  'Korean BBQ',
#  'Fusion',
#  'Canadian',
#  'Breakfast',
#  'Cajun',
#  'New Mexican',
#  'Belgian',
#  'Cuban',
#  'Taco',
#  'Caribbean',
#  'Polish',
#  'Deli',
#  'British',
#  'California',
#  'Others',
#  'Eastern European',
#  'Creole',
#  'Ramen',
#  'Ukrainian',
#  'Hawaiian',
#  'Patisserie',
#  'Yum Cha',
#  'Pacific Northwest',
#  'Tea',
#  'Moroccan',
#  'Burmese',
#  'Dim Sum',
#  'Crepes',
#  'Fish and Chips',
#  'Russian',
#  'Continental',
#  'South Indian',
#  'North Indian',
#  'Salad',
#  'Finger Food',
#  'Mandi',
#  'Turkish',
#  'Kerala',
#  'Pakistani',
#  'Biryani',
#  'Street Food',
#  'Nepalese',
#  'Goan',
#  'Iranian',
#  'Mughlai',
#  'Rajasthani',
#  'Mithai',
#  'Maharashtrian',
#  'Gujarati',
#  'Rolls',
#  'Momos',
#  'Parsi',
#  'Modern Indian',
#  'Andhra',
#  'Tibetan',
#  'Kebab',
#  'Chettinad',
#  'Bengali',
#  'Assamese',
#  'Naga',
#  'Hyderabadi',
#  'Awadhi',
#  'Afghan',
#  'Lucknowi',
#  'Charcoal Chicken',
#  'Mangalorean',
#  'Egyptian',
#  'Malwani',
#  'Armenian',
#  'Roast Chicken',
#  'Indonesian',
#  'Western',
#  'Dimsum',
#  'Sunda',
#  'Kiwi',
#  'Asian Fusion',
#  'Pan Asian',
#  'Balti',
#  'Scottish',
#  'Cantonese',
#  'Sri Lankan',
#  'Khaleeji',
#  'South African',
#  'Drinks Only',
#  'Durban',
#  'World Cuisine',
#  'Izgara',
#  'Home-made',
#  'Giblets',
#  'Fresh Fish',
#  'Restaurant Cafe',
#  'Kumpir',
#  'Döner',
#  'Turkish Pizza',
#  'Ottoman',
#  'Old Turkish Bars',
#  'Kokoreç']

# %%
# 1. Quantos restaurantes únicos estão registrados?
df2['restaurant_id'].nunique()
# Out:
# 6929

# %% [markdown]
# ## 2. Quantos países únicos estão registrados?

# %%
# 2. Quantos países únicos estão registrados?
df2["country"].nunique()
# Out:
# 15

# %% [markdown]
# # 3. Quantas cidades únicas estão registradas?

# %%
# 3. Quantas cidades únicas estão registradas?
df2["city"].nunique()

# ou df2.loc[:,"city"].nunique()
# Out:
# 125

# %% [markdown]
# # 4. Qual o total de avaliações feitas?

# %%
# 4. Qual o total de avaliações feitas?
df2["votes"].sum()
# Out:
# 4194533

# %% [markdown]
# # 5. Qual o total de tipos de culinária registrados?

# %%
df2.columns
# Out:
# Index(['restaurant_id', 'restaurant_name', 'country', 'city', 'address',
#        'locality', 'locality_verbose', 'longitude', 'latitude', 'cuisines',
#        'price_type', 'average_cost_for_two', 'currency', 'has_table_booking',
#        'has_online_delivery', 'is_delivering_now', 'aggregate_rating',
#        'rating_color', 'color_name', 'rating_text', 'votes'],
#       dtype='object')

# %%
# 5. Qual o total de tipos de culinária registrados?
df2["cuisines"].nunique()
# Out:
# 165

# %% [markdown]
# # País

# %% [markdown]
# ## 1. Qual o nome do país que possui mais cidades registradas?

# %%
# 1. Qual o nome do país que possui mais cidades registradas?

# sape
# sa...ída
## o nome do país que possui a maior quantidade de cidades registradas na base de dados

# p...processo
# 'selecionar' a coluna cidades e 'agrupar por' país, dentro desse agrupamento 'localizar'
# o país que possui o maior número de cidades agrupadas

# e...ntrada
# v1

(df2.loc[:,["city","country"]]
    .groupby("country")
    .nunique()
    .sort_values("city",ascending=False)
    .reset_index()
    .iloc[0,0])
# Out:
# 'India'

# %% [markdown]
# ## 2. Qual o nome do país que possui mais restaurantes registrados?

# %%
(df2.loc[:,["country","restaurant_id"]]
    .groupby("country")
    .nunique()
    .sort_values("restaurant_id",ascending=False)
    .reset_index()
    .head(10))
    #.iloc[0,0])
# Out:
#                     country  restaurant_id
# 0                     India           3111
# 1  United States of America           1374
# 2                   England            400
# 3              South Africa            346
# 4      United Arab Emirates            300
# 5                    Brazil            240
# 6                New Zeland            239
# 7                 Australia            180
# 8                    Canada            180
# 9                    Turkey            159

# %% [markdown]
# ## 3. Qual o nome do país que possui mais restaurantes com o nível de preço igual a 4 registrados?

# %%
(df2.loc[df2["price_type"]=="gourmet",["country","price_type"]]
    .groupby("country")
    .nunique()
    .sort_values("price_type",ascending=False)
    .reset_index()
    .iloc[0,0])
# Out:
# 'Australia'

# %% [markdown]
# ## 4. Qual o nome do país que possui a maior quantidade de tipos de culinária distintos?

# %%
(df2.loc[:,["cuisines","country"]]
    .groupby("country")
    .nunique()
    .sort_values("cuisines",ascending=False)
    .reset_index()
    .iloc[0,0])
# Out:
# 'India'

# %% [markdown]
# ## 5. Qual o nome do país que possui a maior quantidade de avaliações feitas?

# %%
(df2.loc[:,["votes","country"]]
    .groupby("country")
    .sum()
    .sort_values("votes", ascending=False)
    .reset_index()
    .iloc[0,0])
# Out:
# 'India'

# %% [markdown]
# ## 6. Qual o nome do país que possui a maior quantidade de restaurantes que fazem entrega?

# %%
(df2.loc[df2['is_delivering_now']==1,['restaurant_id','country']]
    .groupby('country')
    .count()
    .sort_values('restaurant_id',ascending=False)
    .reset_index()
    .iloc[0,0])
# Out:
# 'India'

# %% [markdown]
# ## 7. Qual o nome do país que possui a maior quantidade de restaurantes que aceitam reservas?

# %%
(df2.loc[df2['has_table_booking']==1,['restaurant_id','country']]
    .groupby('country')
    .count()
    .sort_values('restaurant_id',ascending=False)
    .reset_index()
    .iloc[0,0])
# Out:
# 'India'

# %% [markdown]
# ## 8. Qual o nome do país que possui, na média, a maior quantidade de avaliações registrada?

# %%
(df2.loc[:,['votes','country']]
    .groupby('country')
    .mean()
    .sort_values('votes',ascending=False)
    .reset_index())
    #.iloc[0,0])
# Out:
#                      country        votes
# 0                  Indonesia  1112.825000
# 1                      India   900.084860
# 2                  Australia   724.205556
# 3                     Turkey   630.144654
# 4                Philippines   604.975000
# 5       United Arab Emirates   591.880000
# 6                     Canada   583.433333
# 7   United States of America   380.165939
# 8                      Qatar   376.325000
# 9               South Africa   236.817919
# 10                New Zeland   219.799163
# 11                 Sri Lanka   151.662500
# 12                   England    99.890000
# 13                 Singapure    22.775000
# 14                    Brazil    12.404167

# %% [markdown]
# ## 9. Qual o nome do país que possui, na média, a maior nota média registrada?

# %%
(df2.loc[:,['aggregate_rating','country']]
    .groupby('country')
    .mean()
    .sort_values('aggregate_rating',ascending=False)
    .reset_index()
    .iloc[0,0])
# Out:
# 'Indonesia'

# %% [markdown]
# ## 10. Qual o nome do país que possui, na média, a menor nota média registrada?

# %%
(df2.loc[:,['aggregate_rating','country']]
    .groupby('country')
    .mean()
    .sort_values('aggregate_rating',ascending=True)
    .reset_index()
    .iloc[0,0])
# Out:
# 'Brazil'

# %% [markdown]
# ## 11. Qual a média de preço de um prato para dois por país?

# %%
# unidade monetáia varia por país, optei por deixar como está

(df2.loc[:,['average_cost_for_two','country']]
    .groupby('country')
    .mean()
    .sort_values('average_cost_for_two', ascending=False)
    .reset_index())
# Out:
#                      country  average_cost_for_two
# 0                  Indonesia         303000.000000
# 1                  Australia         138959.783333
# 2                  Sri Lanka           2579.375000
# 3                Philippines           1227.825000
# 4                      India            704.400514
# 5               South Africa            339.228324
# 6                      Qatar            174.000000
# 7       United Arab Emirates            153.716667
# 8                  Singapure            141.437500
# 9                     Brazil            138.812500
# 10                    Turkey            128.584906
# 11                New Zeland             62.154812
# 12  United States of America             55.029840
# 13                   England             43.510000
# 14                    Canada             41.861111

# %% [markdown]
# # Cidade

# %% [markdown]
# ## 1. Qual o nome da cidade que possui mais restaurantes registrados?

# %%
    (df2.loc[:,['restaurant_id','city','country']]
    .groupby(['city','country'])
    .count()
    .sort_values('restaurant_id',ascending=False)
    .reset_index()
    .head(10))
# Out:
#         city                   country  restaurant_id
# 0  Abu Dhabi      United Arab Emirates             80
# 1     Mysore                     India             80
# 2    Glasgow                   England             80
# 3        Goa                     India             80
# 4   Guwahati                     India             80
# 5   Hamilton                New Zeland             80
# 6    Houston  United States of America             80
# 7     Indore                     India             80
# 8     Jaipur                     India             80
# 9     Kanpur                     India             80

# %% [markdown]
# ## 2. Qual o nome da cidade que possui mais restaurantes com nota média acima de 4?

# %%
# no gab considerou notas >=4. Optei por deixar >4 por estar mais coerente com a pergunta de negócio.

# (df2.loc[df2['aggregate_rating']>4,['restaurant_id','city']]
#     .groupby('city')
#     .count()
#     .sort_values('restaurant_id',ascending=False)
#     .reset_index()
#     .iloc[0,0])

(df2.loc[df2['aggregate_rating']>4,['restaurant_id','city','country']]
    .groupby(['city','country'])
    .count()
    .sort_values('restaurant_id',ascending=False)
    .reset_index()
    .head(7))
# Out:
#         city                   country  restaurant_id
# 0  Bangalore                     India             79
# 1     London                   England             78
# 2    Houston  United States of America             75
# 3    Jakarta                 Indonesia             74
# 4    Chennai                     India             72
# 5   Auckland                New Zeland             72
# 6    Kolkata                     India             70

# %% [markdown]
# ### *restaurantes brasileiros no banco de dados, agrupador por cidade e avaliação (fiz por conta)

# %%
df2.loc[df2['country']=='Brazil',['aggregate_rating','city','restaurant_name']].sort_values('aggregate_rating',ascending=False)
# Out:
#      aggregate_rating            city                        restaurant_name
# 249               4.9       São Paulo                    Skye - Hotel Unique
# 191               4.9  Rio de Janeiro                      Braseiro da Gávea
# 273               4.9       São Paulo                   Z Deli Sandwich Shop
# 230               4.9  Rio de Janeiro                              Aprazível
# 177               4.9  Rio de Janeiro                    Churrascaria Palace
# 218               4.9  Rio de Janeiro                           Sushi Leblon
# 271               4.8       São Paulo                                 D.O.M.
# 317               4.8       São Paulo                                 Mocotó
# 197               4.8  Rio de Janeiro                      Garota de Ipanema
# 166               4.8  Rio de Janeiro                           Irajá Gastrô
# 175               4.8  Rio de Janeiro                               Carretão
# 165               4.8  Rio de Janeiro                           Fogo de Chão
# 174               4.7  Rio de Janeiro                                   Bibi
# 296               4.7       São Paulo                                   Maní
# 179               4.7  Rio de Janeiro                       Marius Degustare
# 199               4.7  Rio de Janeiro                   Zazá Bistrô Tropical
# 196               4.7  Rio de Janeiro                               Carretão
# 269               4.7       São Paulo                    A Figueira Rubaiyat
# 190               4.7  Rio de Janeiro                              TT Burger
# 235               4.7  Rio de Janeiro                      Aconchego Carioca
# 315               4.6       São Paulo                             Coffee Lab
# 198               4.6  Rio de Janeiro                                 Venga!
# 301               4.6       São Paulo                         Terraço Itália
# 214               4.6  Rio de Janeiro                                   Bibi
# 205               4.6  Rio de Janeiro                                   Bráz
# 251               4.6       São Paulo                        Les 3 Brasseurs
# 240               4.6       São Paulo               Cantina Famiglia Mancini
# 169               4.6  Rio de Janeiro                    Confeitaria Colombo
# 195               4.6  Rio de Janeiro                             Balada Mix
# 194               4.6  Rio de Janeiro                                  Astor
# 318               4.6       São Paulo                                 Veloso
# 250               4.5       São Paulo                       Butcher's Market
# 316               4.5       São Paulo                         Esquina Mocotó
# 252               4.5       São Paulo                                   Ritz
# 206               4.5  Rio de Janeiro                            Mamma Jamma
# 272               4.5       São Paulo                        Mori Otha Sushi
# 209               4.5  Rio de Janeiro                              Guacamole
# 231               4.5  Rio de Janeiro                         Bar do Mineiro
# 178               4.5  Rio de Janeiro                           La Trattoria
# 158               4.5        Brasília                               Taco Pep
# 278               0.0       São Paulo                           Ristorantino
# 170               0.0  Rio de Janeiro               La Bocca Bar e Trattoria
# 160               0.0  Rio de Janeiro                                    Org
# 153               0.0        Brasília                 Restaurante dos Amigos
# 152               0.0        Brasília             NAVE MÃE FAST FOOD GOURMET
# 151               0.0        Brasília                       Capricho Mineiro
# 139               0.0        Brasília                   Galeteria Beira Lago
# 289               0.0       São Paulo                  Tanka - Hotel Akasaka
# 259               0.0       São Paulo                                Le Bife
# 291               0.0       São Paulo                  Bar do Luiz Fernandes
# 200               0.0  Rio de Janeiro                Le Bistrot du Cuisinier

# %% [markdown]
# ## 3. Qual o nome da cidade que possui mais restaurantes com nota média abaixo de 2.5?

# %%
# (df2.loc[df2['aggregate_rating']<2.5,['restaurant_id','city']]
#     .groupby('city')
#     .count()
#     .sort_values('restaurant_id',ascending=False)
#     .reset_index()
#     .iloc[0,0])

(df2.loc[df2['aggregate_rating']<2.5,['restaurant_id','city','country']]
    .groupby(['city','country'])
    .count()
    .sort_values('restaurant_id',ascending=False)
    .reset_index()
    .head(7))
# Out:
#              city       country  restaurant_id
# 0         Gangtok         India             33
# 1            Ooty         India             19
# 2       São Paulo        Brazil             16
# 3        Brasília        Brazil             15
# 4  Rio de Janeiro        Brazil             12
# 5      Manchester       England              7
# 6         Clarens  South Africa              4

# %% [markdown]
# ## 4. Qual o nome da cidade que possui o maior valor médio de um prato para dois?

# %%
# unidade monetáia varia por país, optei por deixar como está

(df2.loc[:,['average_cost_for_two','city']]
    .groupby('city')
    .mean()
    .sort_values('average_cost_for_two',ascending=False)
    .reset_index()
    .iloc[0,0])
# Out:
# 'Adelaide'

# %% [markdown]
# ## 5. Qual o nome da cidade que possui a maior quantidade de tipos de culinária distintas?

# %%
# (df2.loc[:,['cuisines','city']]
#     .groupby('city')
#     .nunique()
#     .sort_values('cuisines',ascending=False)
#     .reset_index()
#     .iloc[0,0])

(df2.loc[:,['cuisines','city','country']]
    .groupby(['city','country'])
    .nunique()
    .sort_values('cuisines',ascending=False)
    .reset_index()
    .head(10))
# Out:
#            city                   country  cuisines
# 0    Birmingham                   England        32
# 1          Doha                     Qatar        31
# 2      Montreal                    Canada        30
# 3     São Paulo                    Brazil        30
# 4    Manchester                   England        30
# 5       Houston  United States of America        30
# 6         Perth                 Australia        29
# 7  Philadelphia  United States of America        29
# 8      Portland  United States of America        28
# 9       Calgary                    Canada        28

# %% [markdown]
# ## 6. Qual o nome da cidade que possui a maior quantidade de restaurantes que fazem reservas?

# %%
df2.columns
# Out:
# Index(['restaurant_id', 'restaurant_name', 'country', 'city', 'address',
#        'locality', 'locality_verbose', 'longitude', 'latitude', 'cuisines',
#        'price_type', 'average_cost_for_two', 'currency', 'has_table_booking',
#        'has_online_delivery', 'is_delivering_now', 'aggregate_rating',
#        'rating_color', 'color_name', 'rating_text', 'votes'],
#       dtype='object')

# %%
(df2.loc[df2['has_table_booking']==1,['restaurant_id','city']]
    .groupby('city')
    .count()
    .sort_values('restaurant_id',ascending=False)
    .reset_index()
    .iloc[0,0])
# Out:
# 'Bangalore'

# %% [markdown]
# ## 7. Qual o nome da cidade que possui a maior quantidade de restaurantes que fazem entregas?

# %%
(df2.loc[df2['is_delivering_now']==1,['restaurant_id','city']]
    .groupby('city')
    .count()
    .sort_values('restaurant_id',ascending=False)
    .reset_index()
    .iloc[0,0])
# Out:
# 'Vadodara'

# %% [markdown]
# ## 8. Qual o nome da cidade que possui a maior quantidade de restaurantes que aceitam pedidos online?

# %%
(df2.loc[df2['has_online_delivery']==1,['restaurant_id','city']]
    .groupby('city')
    .count()    
    .sort_values('restaurant_id',ascending=False)
    .reset_index()
    .iloc[0,0])
# Out:
# 'Bhopal'

# %% [markdown]
# # Restaurantes

# %% [markdown]
# ## 1. Qual o nome do restaurante que possui a maior quantidade de avaliações?

# %%
(df2.loc[:,['restaurant_name','votes']]
    .sort_values('votes',ascending=False)
    .iloc[0,0])
# Out:
# 'Bawarchi'

# %% [markdown]
# ## 2. Qual o nome do restaurante com a maior nota média?

# %%
# se houver empate, pega o restaurante com menor id (mais antigo registro na base)

(df2.loc[:,['restaurant_name','aggregate_rating','restaurant_id']]
    .sort_values(['aggregate_rating','restaurant_id'],ascending=[False,True])
    .iloc[0,0])
# Out:
# 'Indian Grill Room'

# %% [markdown]
# ## 3. Qual o nome do restaurante que possui o maior valor de uma prato para duas pessoas?

# %%
df2['restaurant_id'].count()
# Out:
# 6929

# %%
df2.columns
# Out:
# Index(['restaurant_id', 'restaurant_name', 'country', 'city', 'address',
#        'locality', 'locality_verbose', 'longitude', 'latitude', 'cuisines',
#        'price_type', 'average_cost_for_two', 'currency', 'has_table_booking',
#        'has_online_delivery', 'is_delivering_now', 'aggregate_rating',
#        'rating_color', 'color_name', 'rating_text', 'votes'],
#       dtype='object')

# %%
(df2.loc[:,['average_cost_for_two','restaurant_name']]
    .sort_values('average_cost_for_two', ascending=False)
    .iloc[0,1])
# Out:
# "d'Arry's Verandah Restaurant"

# %% [markdown]
# ## 4. Qual o nome do restaurante de tipo de culinária brasileira que possui a menor média de avaliação?

# %%
(df2.loc[df2['cuisines']=='Brazilian',['restaurant_name','aggregate_rating','restaurant_id']]
    .sort_values(['aggregate_rating','restaurant_id'],ascending=[True,True])
    .iloc[0,0])
# Out:
# 'Loca Como tu Madre'

# %% [markdown]
# ## 5. Qual o nome do restaurante de tipo de culinária brasileira, e que é do Brasil, que possui a maior média de avaliação?

# %%
(df2.loc[df2['cuisines']=='Brazilian',['restaurant_name','aggregate_rating','restaurant_id']]
    .sort_values(['aggregate_rating','restaurant_id'],ascending=[False,True])
    .iloc[0,0])
# Out:
# 'Braseiro da Gávea'

# %% [markdown]
# ## 6. Os restaurantes que aceitam pedido online são também, na média, os restaurantes que mais possuem avaliações registradas?

# %%
print(df2.loc[df2['has_online_delivery']==0,['restaurant_id','votes']]['votes'].mean())
print(df2.loc[df2['has_online_delivery']==1,['restaurant_id','votes']]['votes'].mean())
print('sim')
# Out:
# 479.4210175516552
# 838.8216639209226
# sim

# %%
# outra fomra

#df2.loc[:,['votes','has_online_delivery']].groupby('has_online_delivery').mean().reset_index()

# %% [markdown]
# ## 7. Os restaurantes que fazem reservas são também, na média, os restaurantes que possuem o maior valor médio de um prato para duas pessoas?

# %%
#desconsiderando unidade monetária que varia por país...

(df2.loc[:,['average_cost_for_two','has_table_booking']]
    .groupby('has_table_booking')
    .mean()
    .sort_values('average_cost_for_two',ascending=False)
    .reset_index())
# Out:
#    has_table_booking  average_cost_for_two
# 0                  1          69998.423810
# 1                  0           3488.596866

# %% [markdown]
# ## 8. Os restaurantes do tipo de culinária japonesa dos Estados Unidos da América possuem um valor médio de prato para duas pessoas maior que as churrascarias americanas (BBQ)?

# %%
print('Valor médio de prato para duas pessoas dos restaurantes do tipo de culinária japonesa dos Estados Unidos da América')
print(df2.loc[(df2['cuisines']=='Japanese')&(df2['country']=='United States of America'),'average_cost_for_two'].mean())
print('Valor médio de prato para duas pessoas das churrascarias americanas (BBQ)')
print(df2.loc[(df2['cuisines']=='BBQ')&(df2['country']=='United States of America'),'average_cost_for_two'].mean())
# Out:
# Valor médio de prato para duas pessoas dos restaurantes do tipo de culinária japonesa dos Estados Unidos da América
# 56.40625
# Valor médio de prato para duas pessoas das churrascarias americanas (BBQ)
# 39.642857142857146

# %%
# outra maneira de fazer

# cond = (df2['country'] == 'United States of America') & ((df2['cuisines']=='BBQ') | (df2['cuisines']=='Japanese'))

# (df2.loc[cond,['average_cost_for_two','cuisines']]
#     .groupby('cuisines')
#     .mean()
#     .sort_values('average_cost_for_two', ascending=False)
#     .reset_index())

# %% [markdown]
# # Tipos de Culinária

# %% [markdown]
# ## 1. Dos restaurantes que possuem o tipo de culinária italiana, qual o nome do restaurante com a maior média de avaliação?

# %%
# (df2.loc[df2['cuisines']=='Italian',['restaurant_id','aggregate_rating','restaurant_name']]
#     .groupby('restaurant_name')
#     .mean()
#     .sort_values(['aggregate_rating','restaurant_id'],ascending=[False,True])
#     .reset_index()
#     .iloc[0,0])

# (df2.loc[df2['cuisines']=='Italian',['restaurant_id','aggregate_rating','restaurant_name']]
#                         .groupby('restaurant_name')
#                         .mean()
#                         .sort_values(['aggregate_rating','restaurant_id'],ascending=[False,True])
#                         .reset_index()
#                         .iloc[0,2])

df_aux = (df2.loc[df2['cuisines']=='Italian',['restaurant_id','aggregate_rating','restaurant_name']]
                        .groupby('restaurant_name')
                        .mean()
                        .sort_values(['aggregate_rating','restaurant_id'],ascending=[False,True])
                        .reset_index())

df_aux
# nome_rest = df_aux.iloc[0,0]
# nota_rest = df_aux.iloc[0,2]

# print(f'Italiana: {nome_rest}', f'\n {nota_rest}/5.0')
# Out:
#                                        restaurant_name  restaurant_id  \
# 0                                Cafe Del Sol Classico   6.501298e+06
# 1                                                Ombra   7.100171e+06
# 2                                             Celino's   7.700796e+06
# 3                         Andre's Cucina & Polenta Bar   1.658768e+07
# 4                             Di Rienzo Grocery & Deli   1.666342e+07
# 5                 Chicago Pizza & Oven Grinder Company   1.673318e+07
# 70                          Frenchie's Italian Cuisine   1.688140e+07
# 71                                          Italiano's   1.688206e+07
# 72                              Franks At Old Mill Inc   1.690927e+07
# 73                                  Fratelli la Bufala   1.692086e+07
# 74                                            Villagio   1.692516e+07
# 75                                      Shells & Sauce   1.697309e+07
# 76                      Settebello Pizzeria Napoletana   1.698022e+07
# 77                                        PizzaPapalis   1.699003e+07
# 78                                              Piatti   1.707154e+07
# 79                           Dough Pizzeria Napoletana   1.715512e+07
# 80                                       Upland Bistro   1.843362e+07
# 81                                        Cafe Mezzuna   2.383100e+04
# 82                                          Cocoa Tree   9.533100e+04
# 83                                               Mocha   8.016900e+05
# 84                                            Frosting   3.600593e+06
# 85                                      Pizza İl Forno   6.005457e+06
# 86                                          Paper Moon   6.201360e+06
# 87                                  Scopa Caffe Cucina   7.100538e+06
# 88                                           Quadrucci   7.300650e+06
# 89                                                Zuka   7.300679e+06
# 90                                         Olive & Oil   7.800374e+06
# 91                            Carluccio's - كارلوتشيوز   1.433260e+07
# 92                                   Ruby Red Flamingo   1.658844e+07
# 93                                    Prego Restaurant   1.659703e+07
# 94                                                Town   1.666432e+07
# 95                              Ristorante Machiavelli   1.671860e+07
# 96                                          Giordano's   1.673456e+07
# 97                                               Coppa   1.680388e+07
# 98                                        Cliff's Edge   1.681037e+07
# 99                                             Scoma's   1.684996e+07
# 100                                  Pizzeria Paradiso   1.687024e+07
# 101                                       Star Pizza 2   1.688511e+07
# 102                                    Enoteca Vespaio   1.691428e+07
# 103                                 Jimmy's Food Store   1.694959e+07
# 104                                            Louie's   1.695097e+07
# 105                                        Pizza House   1.699220e+07
# 106                                           La Viola   1.701312e+07
# 107                                      Nello's Pizza   1.702808e+07
# 108                                      Buon Appetito   1.706823e+07
# 109                                          Falalalah   1.801969e+07
# 110                   The Luggage Room Kitchen And Bar   1.833789e+07
# 111                                       Pasta Street   1.840874e+07
# 112                                     Oso Ristorante   1.848451e+07
# 113                                  PizzaExpress Live   1.856456e+07
# 114                                      Kermit Manila   1.866486e+07
# 115                  The Poona Project by PizzaExpress   1.866895e+07
# 116                         Mama Lou's Italian Kitchen   1.240692e+07
# 117                                         CIBO house   9.649700e+04
# 118                      Harbour Court - The Kingsbury   5.800678e+06
# 119                                   Tortellino D'Oro   6.500965e+06
# 120                                    Pasta Di Piazza   6.900277e+06
# 121                                              Cielo   6.900400e+06
# 122                                              Prego   7.000135e+06
# 123                                         Floriditas   7.100811e+06
# 124                         The Battlefield Restaurant   7.700672e+06
# 125                                             Eataly   1.133433e+07
# 126                                           Basilico   1.244208e+07
# 127                               Galileo Buona Cucina   1.659600e+07
# 128                            Il Lido Italian Canteen   1.659607e+07
# 129                                 Restaurant Da Emma   1.663590e+07
# 130                                    La Porto A Casa   1.666334e+07
# 131                                      C&O Trattoria   1.680884e+07
# 132                                          Zuni Café   1.685297e+07
# 133                                          il Canale   1.687448e+07
# 134                         Santa Barbara Italian Cafe   1.688469e+07
# 135                          Campisi's Egyptian Lounge   1.694038e+07
# 136                                           Bencotto   1.707492e+07
# 137                                             Fiamma   1.714723e+07
# 138                                     Mama Ricotta's   1.714768e+07
# 139                                   IL Sogno Osteria   1.715618e+07
# 140                                           Domenica   1.724467e+07
# 141                                            Roger's   1.822901e+07
# 142                    Paul's Homemade Pasta & Lasagna   1.823201e+07
# 143                                        CALCUTTA 64   1.837710e+07
# 144                                         La Gustosa   1.852848e+07
# 145                                             Nazara   1.865396e+07
# 146                        Urbanbird Cafe & Restaurant   1.868315e+07
# 147                                         The Monroe   1.871535e+07
# 148                                    La Pino'z Pizza   1.887794e+07
# 149                                          San Carlo   6.851060e+06
# 150                                       La Trattoria   1.194452e+07
# 151                        Afraa Restaurant And Lounge   2.085200e+04
# 152                                    The Bikers Cafe   2.434200e+04
# 153                                            Capeesh   7.513100e+04
# 154                                    Life Grand Cafe   7.576400e+04
# 155                     Cocoa Tree - The Avenue Regent   9.532900e+04
# 156                                    Mamu's Infusion   1.018840e+05
# 157                                                WTF   1.030650e+05
# 158                                            Pyramid   1.240820e+05
# 159                                    Tuscany Gardens   1.302130e+05
# 160                                  Summer House Cafe   3.074900e+05
# 161                                          On The Go   3.000016e+06
# 162                                        Hidden Fork   3.002145e+06
# 163                                      Thyme & Whisk   3.202122e+06
# 164                              Lovely's Baker Street   3.301177e+06
# 165                                Jalpaan Dining Saga   3.600265e+06
# 166                                         Taka Pizza   3.700649e+06
# 167                                     Falafel Lovers   3.800238e+06
# 168                                  Whight & Co. Cafe   5.800871e+06
# 169                                   Friuli Trattoria   6.302438e+06
# 170                                      Casa do Sardo   7.302471e+06
# 171                                         Al Firenze   7.800581e+06
# 172                                      Tony Tomatoes   1.658917e+07
# 173                          Francoforte Spaghetti Bar   1.660077e+07
# 174                         Famoso Neapolitan Pizzeria   1.663166e+07
# 175                                            Bottega   1.663375e+07
# 176                                Pizzeria Napoletana   1.663567e+07
# 177                      Pasquale's Italian Restaurant   1.667891e+07
# 178                                              Babbo   1.675991e+07
# 179                                             Bricco   1.679470e+07
# 180                                             Bestia   1.683580e+07
# 181                                     Scala's Bistro   1.684996e+07
# 182                                        È Tutto Qua   1.685303e+07
# 183                            Scalini's Pizza & Pasta   1.694703e+07
# 184                            Maggiano's Little Italy   1.699782e+07
# 185                             Oregano's Pizza Bistro   1.702823e+07
# 186                                        Fumo Attico   1.852654e+07
# 187                 The Bandra Project by PizzaExpress   1.854886e+07
# 188                                            Vapiano   8.702091e+06
# 189                                    The Last Course   9.388922e+06
# 190                                             Diggin   9.434974e+06
# 191                                    Tales & Spirits   1.256377e+07
# 192                                            Taverna   1.693130e+07
# 193                                       PizzaExpress   4.755500e+04
# 194                               360 Degrees Pizzeria   9.005270e+05
# 195                                      Bakes & Beans   2.200008e+06
# 196                                    Mauj Restaurant   2.500075e+06
# 197                           Olive & Honey Restaurant   2.600590e+06
# 198                                       Mummys Pizza   3.201351e+06
# 199                                        Neon Castle   3.600478e+06
# 200                     MCA Ministry of Cheesy Affairs   3.800691e+06
# 201                              Pizzeria Vaatika Cafe   3.900059e+06
# 321          3.400000
# 322          3.400000
# 323          3.400000
# 324          3.300000
# 325          3.300000
# 326          3.300000
# 327          3.200000
# 328          3.100000
# 329          3.100000
# 330          3.000000
# 331          2.800000
# 332          2.600000
# 333          2.300000
# 334          0.000000
# 335          0.000000
# 336          0.000000
# 337          0.000000
# 338          0.000000
# 339          0.000000
# 340          0.000000
# 341          0.000000

# %% [markdown]
# ## 2. Dos restaurantes que possuem o tipo de culinária italiana, qual o nome do restaurante com a menor média de avaliação?

# %%
(df2.loc[df2['cuisines']=='Italian',['restaurant_id','restaurant_name','aggregate_rating']]
    .groupby('restaurant_name')
    .mean()
    .sort_values(['aggregate_rating','restaurant_id'],ascending=[True,True])
    .reset_index()
    .iloc[0,0])
# Out:
# 'Avenida Paulista'

# %% [markdown]
# ## 3. Dos restaurantes que possuem o tipo de culinária americana, qual o nome do restaurante com a maior média de avaliação?

# %%
cond_line = df2['cuisines'] == 'American'
cols = ['restaurant_id','restaurant_name','aggregate_rating']


(df2.loc[cond_line,cols]
    .groupby('restaurant_name')
    .mean()
    .sort_values(['aggregate_rating','restaurant_id'],ascending=[False,True])
    .reset_index()
    .iloc[0,0])
# Out:
# 'OEB Breakfast Co.'

# %% [markdown]
# ## 4. Dos restaurantes que possuem o tipo de culinária americana, qual o nome do restaurante com a menor média de avaliação?

# %%
(df2.loc[df2['cuisines']=='American',['restaurant_id','restaurant_name','aggregate_rating']]
    .groupby('restaurant_name')
    .mean()
    .sort_values(['aggregate_rating','restaurant_id'],ascending=[True,True])
    .reset_index()
    .iloc[0,0])
# Out:
# 'Alston Bar & Beef'

# %% [markdown]
# ## 5. Dos restaurantes que possuem o tipo de culinária árabe, qual o nome do restaurante com a maior média de avaliação?

# %%
df_aux = (df2.loc[df2['cuisines'] == 'Arabian',['restaurant_id','restaurant_name','aggregate_rating']]
                     .groupby('restaurant_name')
                     .mean()
                     .sort_values(['aggregate_rating','restaurant_id'],ascending=[False,True])
                     .reset_index())
        
nome_rest = df_aux.iloc[0,0]
nota_rest = df_aux.iloc[0,2]

print(nome_rest)
# Out:
# Mandi@36

# %%
(df2.loc[df2['cuisines']=='Arabian',['restaurant_id','restaurant_name','aggregate_rating']]
    .groupby('restaurant_name')
    .mean()
    .sort_values(['aggregate_rating','restaurant_id'], ascending=[False,True])
    .reset_index()
    .iloc[0,0])
# Out:
# 'Mandi@36'

# %% [markdown]
# ## 6. Dos restaurantes que possuem o tipo de culinária árabe, qual o nome do restaurante com a menor média de avaliação?

# %%
print(df2.loc[:,'country'].unique().tolist())
# Out:
# ['Philippines', 'Brazil', 'Australia', 'United States of America', 'Canada', 'Singapure', 'United Arab Emirates', 'India', 'Indonesia', 'New Zeland', 'England', 'Qatar', 'South Africa', 'Sri Lanka', 'Turkey']

# %%
(df2.loc[df2['cuisines']=='Arabian',['restaurant_id','restaurant_name','aggregate_rating']]
    .groupby('restaurant_name')
    .mean()
    .sort_values(['aggregate_rating','restaurant_id'],ascending=[True,True])
    .reset_index()
    .iloc[0,0])
# Out:
# 'Raful'

# %% [markdown]
# ## 7. Dos restaurantes que possuem o tipo de culinária japonesa, qual o nome do restaurante com a maior média de avaliação?

# %%
(df2.loc[df2['cuisines']=='Japanese',['restaurant_id','restaurant_name','aggregate_rating']]
    .groupby('restaurant_name')
    .mean()
    .sort_values(['aggregate_rating','restaurant_id'],ascending=[False,True])
    .reset_index()
    .iloc[0,0])
# Out:
# 'Sushi Samba'

# %% [markdown]
# ## 8. Dos restaurantes que possuem o tipo de culinária japonesa, qual o nome do restaurante com a menor média de avaliação?

# %%
(df2.loc[df2['cuisines']=='Japanese',['restaurant_id','restaurant_name','aggregate_rating']].groupby('restaurant_name')
    .mean()
    .sort_values(['aggregate_rating','restaurant_id'],ascending=[True,True])
    .reset_index()
    .iloc[0,0])
# Out:
# 'Banzai Sushi'

# %% [markdown]
# ## 9. Dos restaurantes que possuem o tipo de culinária caseira, qual o nome do restaurante com a maior média de avaliação?

# %%
(df2.loc[df2['cuisines']=='Home-made',['restaurant_id','restaurant_name','aggregate_rating']]
    .sort_values('aggregate_rating',ascending=False)
    .reset_index()
    .iloc[0,2])
# Out:
# 'Kanaat Lokantası'

# %% [markdown]
# ## 10. Dos restaurantes que possuem o tipo de culinária caseira, qual o nome do restaurante com a menor média de avaliação?

# %%
(df2.loc[df2['cuisines']=='Home-made',['restaurant_name','aggregate_rating']]
    .sort_values('aggregate_rating',ascending=True)
    .iloc[0,0])
# Out:
# 'GurMekan Restaurant'

# %% [markdown]
# ## 11. Qual o tipo de culinária que possui o maior valor médio de um prato para duas pessoas?

# %%
df2.columns
# Out:
# Index(['restaurant_id', 'restaurant_name', 'country', 'city', 'address',
#        'locality', 'locality_verbose', 'longitude', 'latitude', 'cuisines',
#        'price_type', 'average_cost_for_two', 'currency', 'has_table_booking',
#        'has_online_delivery', 'is_delivering_now', 'aggregate_rating',
#        'rating_color', 'color_name', 'rating_text', 'votes'],
#       dtype='object')

# %%
# maior valor médio
(df2.loc[:,['cuisines','average_cost_for_two']]
    .groupby('cuisines')
    .mean()
    .sort_values('average_cost_for_two',ascending=False)
    .reset_index()
    .head(1))

# maior valor
#df2.loc[:,['cuisines','average_cost_for_two']].groupby('cuisines').max().sort_values('average_cost_for_two',ascending=False).reset_index()
# Out:
#             cuisines  average_cost_for_two
# 0  Modern Australian          1.470693e+06

# %% [markdown]
# ## 12. Qual o tipo de culinária que possui a maior nota média?

# %%
(df2.loc[:,['cuisines','aggregate_rating']]
    .groupby('cuisines')
    .mean()
    .sort_values('aggregate_rating',ascending=False)
    .reset_index()
    .iloc[0,0])
# Out:
# 'Others'

# %% [markdown]
# ## 13. Qual o tipo de culinária que possui mais restaurantes que aceitam pedidos online e fazem entregas?

# %%
line_cond = (df2['has_online_delivery']==1) & (df2['is_delivering_now']==1)
cols = ['cuisines','restaurant_id']

df2.loc[line_cond,cols].groupby('cuisines').count().sort_values('restaurant_id',ascending=False).reset_index().head(1)
# Out:
#        cuisines  restaurant_id
# 0  North Indian            317
